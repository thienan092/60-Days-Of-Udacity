# %% [markdown]
# # Setting Up Enviroment.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import matplotlib.pyplot as plt

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms
from sklearn.model_selection import KFold
import utils

# %% [markdown]
# ## Load MNIST Data

# %%
# Define a transform to normalize the data
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize((0.5,), (0.5,)),
                              ])

# Download and load the training data`b
teacher_data = datasets.MNIST('~/.pytorch/MNIST_data/', download=True, train=True, transform=transform)
student_data = datasets.MNIST('~/.pytorch/MNIST_data/', download=True, train=False, transform=transform)

# %% [markdown]
# Divide the public data to train/test sets

# %%
kf = KFold(n_splits=2)

# %%
student_train = None
student_test = None
for i, (train_index, test_index) in enumerate(kf.split(student_data)):
    student_train = torch.utils.data.Subset(student_data, train_index)
    student_test = torch.utils.data.Subset(student_data, test_index)

# %% [markdown]
# ## Hyper Parameters

# %%
num_teachers = 200
num_labels = 10
num_examples = 2048
batch_size = 2048

# %% [markdown]
# For training

# %%
epochs = 15
steps = 0
running_loss = 0
print_every = 5

# %% [markdown]
# ## CUDA device

# %%
# Use GPU if it's available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# # Training Teachers

# %% [markdown]
# Teachers

# %%
class Teacher(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(784, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 64)
        self.fc4 = nn.Linear(64, 10)
        
    def forward(self, x):
        # make sure input tensor is flattened
        x = x.view(x.shape[0], -1)
        
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.log_softmax(self.fc4(x), dim=1)
        
        return x
    
classifiers = [None for _ in range(num_teachers)]
for i in range(num_teachers):
    classifiers[i] = Teacher()

# %% [markdown]
# Training teachers

# %%
kf = KFold(n_splits=num_teachers)

# %%
for t_i, (_, data_index) in enumerate(kf.split(teacher_data)):
    print ("Training model: {}".format(t_i))
    classifier = classifiers[t_i]
    
    data = torch.utils.data.Subset(teacher_data, data_index)
    
    kf_train = KFold(n_splits=2)
    for i, (train_index, test_index) in enumerate(kf_train.split(data)):
        train = torch.utils.data.Subset(data, train_index)
        test = torch.utils.data.Subset(data, test_index)
        
        trainloader = torch.utils.data.DataLoader(train, batch_size=batch_size, shuffle=True)
        testloader = torch.utils.data.DataLoader(test, batch_size=batch_size)

        criterion = nn.NLLLoss()

        # Only train the classifier parameters, feature parameters are frozen
        optimizer = optim.Adam(classifier.parameters(), lr=0.003)

        classifier.to(device);

        for epoch in range(epochs):
            for inputs, labels in trainloader:
                steps += 1
                # Move input and label tensors to the default device
                inputs, labels = inputs.to(device), labels.to(device)

                optimizer.zero_grad()

                logps = classifier.forward(inputs)
                loss = criterion(logps, labels)
                loss.backward()
                optimizer.step()

                running_loss += loss.item()

            if (epoch+1) % print_every == 0:
                test_loss = 0
                accuracy = 0
                classifier.eval()
                with torch.no_grad():
                    for inputs, labels in testloader:
                        inputs, labels = inputs.to(device), labels.to(device)
                        logps = classifier.forward(inputs)
                        batch_loss = criterion(logps, labels)

                        test_loss += batch_loss.item()

                        # Calculate accuracy
                        ps = torch.exp(logps)
                        top_p, top_class = ps.topk(1, dim=1)
                        equals = top_class == labels.view(*top_class.shape)
                        accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

                print(f"Epoch {epoch+1}/{epochs}.. "
                      f"Train loss: {running_loss/print_every:.3f}.. "
                      f"Test loss: {test_loss/len(testloader):.3f}.. "
                      f"Test accuracy: {accuracy/len(testloader):.3f}")
                running_loss = 0
                classifier.train()
        break
# Out:
# Training model: 0
# Epoch 5/30.. Train loss: 2.203.. Test loss: 2.020.. Test accuracy: 0.533
# Epoch 10/30.. Train loss: 1.613.. Test loss: 1.339.. Test accuracy: 0.667
# Epoch 15/30.. Train loss: 0.846.. Test loss: 0.854.. Test accuracy: 0.760
# Epoch 20/30.. Train loss: 0.361.. Test loss: 0.760.. Test accuracy: 0.800
# Epoch 25/30.. Train loss: 0.117.. Test loss: 0.849.. Test accuracy: 0.813
# Epoch 30/30.. Train loss: 0.029.. Test loss: 0.993.. Test accuracy: 0.820
# Training model: 1
# Epoch 5/30.. Train loss: 2.168.. Test loss: 2.032.. Test accuracy: 0.247
# Epoch 10/30.. Train loss: 1.638.. Test loss: 1.566.. Test accuracy: 0.553
# Epoch 15/30.. Train loss: 0.998.. Test loss: 0.981.. Test accuracy: 0.713
# Epoch 20/30.. Train loss: 0.494.. Test loss: 0.772.. Test accuracy: 0.753
# Epoch 25/30.. Train loss: 0.203.. Test loss: 0.786.. Test accuracy: 0.760
# Epoch 30/30.. Train loss: 0.057.. Test loss: 0.843.. Test accuracy: 0.760
# Training model: 2
# Epoch 5/30.. Train loss: 2.202.. Test loss: 2.051.. Test accuracy: 0.280
# Epoch 10/30.. Train loss: 1.611.. Test loss: 1.442.. Test accuracy: 0.593
# Epoch 15/30.. Train loss: 0.829.. Test loss: 1.109.. Test accuracy: 0.660
# Epoch 20/30.. Train loss: 0.386.. Test loss: 1.105.. Test accuracy: 0.700
# Epoch 25/30.. Train loss: 0.157.. Test loss: 1.213.. Test accuracy: 0.747
# Epoch 30/30.. Train loss: 0.056.. Test loss: 1.369.. Test accuracy: 0.747
# Training model: 3
# Epoch 5/30.. Train loss: 2.217.. Test loss: 2.117.. Test accuracy: 0.360
# Epoch 10/30.. Train loss: 1.751.. Test loss: 1.603.. Test accuracy: 0.473
# Epoch 15/30.. Train loss: 0.995.. Test loss: 1.146.. Test accuracy: 0.567
# Epoch 20/30.. Train loss: 0.497.. Test loss: 1.005.. Test accuracy: 0.687
# Epoch 25/30.. Train loss: 0.243.. Test loss: 1.011.. Test accuracy: 0.707
# Epoch 30/30.. Train loss: 0.100.. Test loss: 1.165.. Test accuracy: 0.720
# Training model: 4
# Epoch 5/30.. Train loss: 2.165.. Test loss: 2.077.. Test accuracy: 0.233
# Epoch 10/30.. Train loss: 1.513.. Test loss: 1.518.. Test accuracy: 0.527
# Epoch 15/30.. Train loss: 0.797.. Test loss: 1.064.. Test accuracy: 0.653
# Epoch 20/30.. Train loss: 0.334.. Test loss: 0.917.. Test accuracy: 0.720
# Epoch 25/30.. Train loss: 0.117.. Test loss: 0.943.. Test accuracy: 0.793
# Epoch 30/30.. Train loss: 0.036.. Test loss: 1.102.. Test accuracy: 0.773
# Training model: 5
# Epoch 5/30.. Train loss: 2.073.. Test loss: 1.893.. Test accuracy: 0.307
# Epoch 10/30.. Train loss: 1.311.. Test loss: 1.221.. Test accuracy: 0.567
# Epoch 15/30.. Train loss: 0.629.. Test loss: 0.880.. Test accuracy: 0.740
# Epoch 20/30.. Train loss: 0.268.. Test loss: 0.809.. Test accuracy: 0.733
# Epoch 25/30.. Train loss: 0.097.. Test loss: 0.973.. Test accuracy: 0.693
# Epoch 30/30.. Train loss: 0.033.. Test loss: 1.063.. Test accuracy: 0.740
# Training model: 6
# Epoch 5/30.. Train loss: 2.168.. Test loss: 1.981.. Test accuracy: 0.240
# Epoch 10/30.. Train loss: 1.466.. Test loss: 1.316.. Test accuracy: 0.580
# Epoch 15/30.. Train loss: 0.754.. Test loss: 0.911.. Test accuracy: 0.680
# Epoch 20/30.. Train loss: 0.396.. Test loss: 0.768.. Test accuracy: 0.760
# Epoch 25/30.. Train loss: 0.177.. Test loss: 0.779.. Test accuracy: 0.773
# Epoch 30/30.. Train loss: 0.062.. Test loss: 0.891.. Test accuracy: 0.773
# Training model: 7
# Epoch 5/30.. Train loss: 2.122.. Test loss: 1.912.. Test accuracy: 0.367
# Epoch 10/30.. Train loss: 1.371.. Test loss: 1.263.. Test accuracy: 0.507
# Epoch 15/30.. Train loss: 0.697.. Test loss: 0.793.. Test accuracy: 0.720
# Epoch 20/30.. Train loss: 0.304.. Test loss: 0.779.. Test accuracy: 0.747
# Epoch 25/30.. Train loss: 0.108.. Test loss: 0.870.. Test accuracy: 0.760
# Epoch 30/30.. Train loss: 0.034.. Test loss: 0.959.. Test accuracy: 0.787
# Training model: 8
# Epoch 5/30.. Train loss: 2.194.. Test loss: 2.037.. Test accuracy: 0.373
# Epoch 10/30.. Train loss: 1.550.. Test loss: 1.338.. Test accuracy: 0.540
# Epoch 15/30.. Train loss: 0.817.. Test loss: 1.139.. Test accuracy: 0.613
# Epoch 20/30.. Train loss: 0.393.. Test loss: 1.285.. Test accuracy: 0.627
# Epoch 25/30.. Train loss: 0.165.. Test loss: 1.343.. Test accuracy: 0.653
# Epoch 30/30.. Train loss: 0.057.. Test loss: 1.409.. Test accuracy: 0.647
# Training model: 9
# Epoch 5/30.. Train loss: 2.130.. Test loss: 1.900.. Test accuracy: 0.487
# Epoch 10/30.. Train loss: 1.336.. Test loss: 1.255.. Test accuracy: 0.593
# Epoch 15/30.. Train loss: 0.595.. Test loss: 0.880.. Test accuracy: 0.707
# Epoch 20/30.. Train loss: 0.262.. Test loss: 0.957.. Test accuracy: 0.733
# Epoch 25/30.. Train loss: 0.095.. Test loss: 1.007.. Test accuracy: 0.707
# Epoch 30/30.. Train loss: 0.027.. Test loss: 1.227.. Test accuracy: 0.733
# Training model: 10
# Epoch 5/30.. Train loss: 2.204.. Test loss: 2.117.. Test accuracy: 0.253
# Epoch 10/30.. Train loss: 1.668.. Test loss: 1.524.. Test accuracy: 0.420
# Epoch 15/30.. Train loss: 0.991.. Test loss: 1.075.. Test accuracy: 0.660
# Epoch 20/30.. Train loss: 0.522.. Test loss: 0.895.. Test accuracy: 0.680
# Epoch 25/30.. Train loss: 0.267.. Test loss: 0.906.. Test accuracy: 0.687
# Epoch 30/30.. Train loss: 0.118.. Test loss: 0.978.. Test accuracy: 0.740
# Training model: 11
# Epoch 5/30.. Train loss: 2.165.. Test loss: 1.948.. Test accuracy: 0.413
# Epoch 10/30.. Train loss: 1.474.. Test loss: 1.187.. Test accuracy: 0.633
# Epoch 15/30.. Train loss: 0.789.. Test loss: 0.802.. Test accuracy: 0.773
# Epoch 20/30.. Train loss: 0.376.. Test loss: 0.786.. Test accuracy: 0.780
# Epoch 25/30.. Train loss: 0.157.. Test loss: 0.718.. Test accuracy: 0.800
# Epoch 30/30.. Train loss: 0.055.. Test loss: 0.870.. Test accuracy: 0.800
# Training model: 12
# Epoch 5/30.. Train loss: 2.163.. Test loss: 2.006.. Test accuracy: 0.447
# Epoch 10/30.. Train loss: 1.439.. Test loss: 1.226.. Test accuracy: 0.687
# Epoch 15/30.. Train loss: 0.625.. Test loss: 1.043.. Test accuracy: 0.647
# Epoch 20/30.. Train loss: 0.255.. Test loss: 1.075.. Test accuracy: 0.733
# Epoch 25/30.. Train loss: 0.083.. Test loss: 1.200.. Test accuracy: 0.753
# Epoch 30/30.. Train loss: 0.023.. Test loss: 1.410.. Test accuracy: 0.747
# Training model: 13
# Epoch 5/30.. Train loss: 2.163.. Test loss: 1.954.. Test accuracy: 0.320
# Epoch 10/30.. Train loss: 1.494.. Test loss: 1.221.. Test accuracy: 0.660
# Epoch 15/30.. Train loss: 0.842.. Test loss: 0.880.. Test accuracy: 0.687
# Epoch 20/30.. Train loss: 0.448.. Test loss: 0.762.. Test accuracy: 0.687
# Epoch 25/30.. Train loss: 0.231.. Test loss: 0.752.. Test accuracy: 0.707
# Epoch 30/30.. Train loss: 0.098.. Test loss: 0.782.. Test accuracy: 0.760
# Training model: 14
# Epoch 5/30.. Train loss: 2.216.. Test loss: 2.056.. Test accuracy: 0.240
# Epoch 10/30.. Train loss: 1.655.. Test loss: 1.310.. Test accuracy: 0.647
# Epoch 15/30.. Train loss: 0.865.. Test loss: 0.871.. Test accuracy: 0.687
# Epoch 20/30.. Train loss: 0.411.. Test loss: 0.813.. Test accuracy: 0.727
# Epoch 25/30.. Train loss: 0.169.. Test loss: 0.935.. Test accuracy: 0.713
# Epoch 30/30.. Train loss: 0.060.. Test loss: 1.000.. Test accuracy: 0.740
# Training model: 15
# Epoch 5/30.. Train loss: 2.174.. Test loss: 1.930.. Test accuracy: 0.427
# Epoch 10/30.. Train loss: 1.399.. Test loss: 1.216.. Test accuracy: 0.620
# Epoch 15/30.. Train loss: 0.679.. Test loss: 0.848.. Test accuracy: 0.680
# Epoch 20/30.. Train loss: 0.310.. Test loss: 0.758.. Test accuracy: 0.793
# Epoch 25/30.. Train loss: 0.117.. Test loss: 0.793.. Test accuracy: 0.827
# Epoch 30/30.. Train loss: 0.038.. Test loss: 0.799.. Test accuracy: 0.833
# Training model: 16
# Epoch 5/30.. Train loss: 2.186.. Test loss: 2.168.. Test accuracy: 0.187
# Epoch 10/30.. Train loss: 1.726.. Test loss: 1.570.. Test accuracy: 0.527
# Epoch 15/30.. Train loss: 1.120.. Test loss: 1.185.. Test accuracy: 0.587
# Epoch 20/30.. Train loss: 0.642.. Test loss: 0.974.. Test accuracy: 0.640
# Epoch 25/30.. Train loss: 0.345.. Test loss: 0.949.. Test accuracy: 0.693
# Epoch 30/30.. Train loss: 0.150.. Test loss: 1.007.. Test accuracy: 0.747
# Training model: 17
# Epoch 5/30.. Train loss: 2.151.. Test loss: 1.926.. Test accuracy: 0.367
# Epoch 10/30.. Train loss: 1.527.. Test loss: 1.405.. Test accuracy: 0.527
# Epoch 15/30.. Train loss: 0.850.. Test loss: 1.025.. Test accuracy: 0.713
# Epoch 20/30.. Train loss: 0.379.. Test loss: 1.012.. Test accuracy: 0.747
# Epoch 25/30.. Train loss: 0.132.. Test loss: 1.237.. Test accuracy: 0.753
# Epoch 30/30.. Train loss: 0.031.. Test loss: 1.457.. Test accuracy: 0.760
# Training model: 18
# Epoch 5/30.. Train loss: 2.163.. Test loss: 2.019.. Test accuracy: 0.227
# Epoch 10/30.. Train loss: 1.569.. Test loss: 1.382.. Test accuracy: 0.520
# Epoch 15/30.. Train loss: 0.925.. Test loss: 0.851.. Test accuracy: 0.727
# Epoch 20/30.. Train loss: 0.485.. Test loss: 0.594.. Test accuracy: 0.820
# Epoch 25/30.. Train loss: 0.217.. Test loss: 0.557.. Test accuracy: 0.847
# Epoch 30/30.. Train loss: 0.085.. Test loss: 0.571.. Test accuracy: 0.867
# Training model: 19
# Epoch 5/30.. Train loss: 2.165.. Test loss: 1.895.. Test accuracy: 0.420
# Epoch 10/30.. Train loss: 1.498.. Test loss: 1.355.. Test accuracy: 0.533
# Epoch 15/30.. Train loss: 0.853.. Test loss: 0.959.. Test accuracy: 0.653
# Epoch 20/30.. Train loss: 0.440.. Test loss: 0.746.. Test accuracy: 0.760
# Epoch 25/30.. Train loss: 0.196.. Test loss: 0.733.. Test accuracy: 0.767
# Epoch 30/30.. Train loss: 0.077.. Test loss: 0.806.. Test accuracy: 0.787
# Training model: 20
# Epoch 5/30.. Train loss: 2.149.. Test loss: 1.911.. Test accuracy: 0.367
# Epoch 10/30.. Train loss: 1.414.. Test loss: 1.038.. Test accuracy: 0.747
# Epoch 15/30.. Train loss: 0.588.. Test loss: 0.564.. Test accuracy: 0.840
# Epoch 20/30.. Train loss: 0.205.. Test loss: 0.562.. Test accuracy: 0.860
# Epoch 25/30.. Train loss: 0.076.. Test loss: 0.611.. Test accuracy: 0.873
# Epoch 30/30.. Train loss: 0.027.. Test loss: 0.673.. Test accuracy: 0.867
# Training model: 21
# Epoch 5/30.. Train loss: 2.162.. Test loss: 2.185.. Test accuracy: 0.260
# Epoch 10/30.. Train loss: 1.508.. Test loss: 1.494.. Test accuracy: 0.553
# Epoch 15/30.. Train loss: 0.733.. Test loss: 1.162.. Test accuracy: 0.627
# Epoch 20/30.. Train loss: 0.285.. Test loss: 1.030.. Test accuracy: 0.707
# Epoch 25/30.. Train loss: 0.086.. Test loss: 1.125.. Test accuracy: 0.653
# Epoch 30/30.. Train loss: 0.025.. Test loss: 1.326.. Test accuracy: 0.687
# Training model: 22
# Epoch 5/30.. Train loss: 2.216.. Test loss: 2.016.. Test accuracy: 0.360
# Epoch 10/30.. Train loss: 1.640.. Test loss: 1.254.. Test accuracy: 0.740
# Epoch 15/30.. Train loss: 0.950.. Test loss: 0.827.. Test accuracy: 0.753
# Epoch 20/30.. Train loss: 0.487.. Test loss: 0.687.. Test accuracy: 0.827
# Epoch 25/30.. Train loss: 0.231.. Test loss: 0.661.. Test accuracy: 0.833
# Epoch 30/30.. Train loss: 0.096.. Test loss: 0.768.. Test accuracy: 0.807
# Training model: 23
# Epoch 5/30.. Train loss: 2.199.. Test loss: 1.990.. Test accuracy: 0.353
# Epoch 10/30.. Train loss: 1.664.. Test loss: 1.389.. Test accuracy: 0.487
# Epoch 15/30.. Train loss: 0.910.. Test loss: 0.984.. Test accuracy: 0.633
# Epoch 20/30.. Train loss: 0.439.. Test loss: 1.036.. Test accuracy: 0.660
# Epoch 25/30.. Train loss: 0.226.. Test loss: 1.063.. Test accuracy: 0.700
# Epoch 30/30.. Train loss: 0.111.. Test loss: 1.170.. Test accuracy: 0.680
# Training model: 24
# Epoch 5/30.. Train loss: 2.212.. Test loss: 2.210.. Test accuracy: 0.207
# Epoch 10/30.. Train loss: 1.685.. Test loss: 1.869.. Test accuracy: 0.320
# Epoch 15/30.. Train loss: 1.006.. Test loss: 1.470.. Test accuracy: 0.507
# Epoch 20/30.. Train loss: 0.485.. Test loss: 1.230.. Test accuracy: 0.533
# Epoch 25/30.. Train loss: 0.215.. Test loss: 1.197.. Test accuracy: 0.593
# Epoch 30/30.. Train loss: 0.090.. Test loss: 1.274.. Test accuracy: 0.633
# Training model: 25
# Epoch 5/30.. Train loss: 2.185.. Test loss: 2.059.. Test accuracy: 0.247
# Epoch 10/30.. Train loss: 1.594.. Test loss: 1.579.. Test accuracy: 0.480
# Epoch 15/30.. Train loss: 0.850.. Test loss: 1.193.. Test accuracy: 0.540
# Epoch 20/30.. Train loss: 0.374.. Test loss: 1.066.. Test accuracy: 0.653
# Epoch 25/30.. Train loss: 0.150.. Test loss: 1.106.. Test accuracy: 0.720
# Epoch 30/30.. Train loss: 0.052.. Test loss: 1.255.. Test accuracy: 0.700
# Training model: 26
# Epoch 5/30.. Train loss: 2.128.. Test loss: 1.941.. Test accuracy: 0.327
# Epoch 10/30.. Train loss: 1.280.. Test loss: 1.151.. Test accuracy: 0.680
# Epoch 15/30.. Train loss: 0.492.. Test loss: 1.011.. Test accuracy: 0.720
# Epoch 20/30.. Train loss: 0.155.. Test loss: 1.167.. Test accuracy: 0.747
# Epoch 25/30.. Train loss: 0.038.. Test loss: 1.297.. Test accuracy: 0.753
# Epoch 30/30.. Train loss: 0.010.. Test loss: 1.543.. Test accuracy: 0.760
# Training model: 27
# Epoch 5/30.. Train loss: 2.192.. Test loss: 2.060.. Test accuracy: 0.560
# Epoch 10/30.. Train loss: 1.558.. Test loss: 1.513.. Test accuracy: 0.527
# Epoch 15/30.. Train loss: 0.884.. Test loss: 1.164.. Test accuracy: 0.680
# Epoch 20/30.. Train loss: 0.443.. Test loss: 1.155.. Test accuracy: 0.727
# Epoch 25/30.. Train loss: 0.197.. Test loss: 1.224.. Test accuracy: 0.713
# Epoch 30/30.. Train loss: 0.066.. Test loss: 1.264.. Test accuracy: 0.767
# Training model: 28
# Epoch 5/30.. Train loss: 2.154.. Test loss: 2.026.. Test accuracy: 0.413
# Epoch 10/30.. Train loss: 1.529.. Test loss: 1.441.. Test accuracy: 0.567
# Epoch 15/30.. Train loss: 0.874.. Test loss: 1.044.. Test accuracy: 0.640
# Epoch 20/30.. Train loss: 0.443.. Test loss: 0.926.. Test accuracy: 0.673
# Epoch 25/30.. Train loss: 0.197.. Test loss: 1.113.. Test accuracy: 0.700
# Epoch 30/30.. Train loss: 0.073.. Test loss: 1.285.. Test accuracy: 0.720
# Training model: 29
# Epoch 5/30.. Train loss: 2.164.. Test loss: 2.059.. Test accuracy: 0.307
# Epoch 10/30.. Train loss: 1.546.. Test loss: 1.529.. Test accuracy: 0.527
# Epoch 15/30.. Train loss: 0.854.. Test loss: 1.146.. Test accuracy: 0.680
# Epoch 20/30.. Train loss: 0.411.. Test loss: 1.217.. Test accuracy: 0.727
# Epoch 25/30.. Train loss: 0.165.. Test loss: 1.441.. Test accuracy: 0.700
# Epoch 30/30.. Train loss: 0.056.. Test loss: 1.664.. Test accuracy: 0.740
# Training model: 30
# Epoch 5/30.. Train loss: 2.146.. Test loss: 1.990.. Test accuracy: 0.487
# Epoch 10/30.. Train loss: 1.470.. Test loss: 1.575.. Test accuracy: 0.480
# Epoch 15/30.. Train loss: 0.892.. Test loss: 1.148.. Test accuracy: 0.627
# Epoch 20/30.. Train loss: 0.479.. Test loss: 1.026.. Test accuracy: 0.673
# Epoch 25/30.. Train loss: 0.236.. Test loss: 0.950.. Test accuracy: 0.707
# Epoch 30/30.. Train loss: 0.102.. Test loss: 1.034.. Test accuracy: 0.713
# Training model: 31
# Epoch 5/30.. Train loss: 2.126.. Test loss: 2.003.. Test accuracy: 0.360
# Epoch 10/30.. Train loss: 1.358.. Test loss: 1.447.. Test accuracy: 0.487
# Epoch 15/30.. Train loss: 0.573.. Test loss: 1.118.. Test accuracy: 0.640
# Epoch 20/30.. Train loss: 0.197.. Test loss: 1.396.. Test accuracy: 0.640
# Epoch 25/30.. Train loss: 0.049.. Test loss: 1.775.. Test accuracy: 0.640
# Epoch 30/30.. Train loss: 0.012.. Test loss: 1.955.. Test accuracy: 0.673
# Training model: 32
# Epoch 5/30.. Train loss: 2.149.. Test loss: 2.008.. Test accuracy: 0.240
# Epoch 10/30.. Train loss: 1.471.. Test loss: 1.282.. Test accuracy: 0.620
# Epoch 15/30.. Train loss: 0.692.. Test loss: 1.082.. Test accuracy: 0.660
# Epoch 20/30.. Train loss: 0.289.. Test loss: 1.208.. Test accuracy: 0.693
# Epoch 25/30.. Train loss: 0.104.. Test loss: 1.480.. Test accuracy: 0.700
# Epoch 30/30.. Train loss: 0.036.. Test loss: 1.848.. Test accuracy: 0.700
# Training model: 33
# Epoch 5/30.. Train loss: 2.152.. Test loss: 1.842.. Test accuracy: 0.353
# Epoch 10/30.. Train loss: 1.495.. Test loss: 1.242.. Test accuracy: 0.627
# Epoch 15/30.. Train loss: 0.849.. Test loss: 0.881.. Test accuracy: 0.747
# Epoch 20/30.. Train loss: 0.423.. Test loss: 0.744.. Test accuracy: 0.773
# Epoch 25/30.. Train loss: 0.181.. Test loss: 0.858.. Test accuracy: 0.767
# Epoch 30/30.. Train loss: 0.073.. Test loss: 0.944.. Test accuracy: 0.807
# Training model: 34
# Epoch 5/30.. Train loss: 2.110.. Test loss: 1.731.. Test accuracy: 0.587
# Epoch 10/30.. Train loss: 1.164.. Test loss: 1.096.. Test accuracy: 0.640
# Epoch 15/30.. Train loss: 0.448.. Test loss: 0.977.. Test accuracy: 0.660
# Epoch 20/30.. Train loss: 0.180.. Test loss: 1.173.. Test accuracy: 0.673
# Epoch 25/30.. Train loss: 0.068.. Test loss: 1.250.. Test accuracy: 0.713
# Epoch 30/30.. Train loss: 0.022.. Test loss: 1.390.. Test accuracy: 0.713
# Training model: 35
# Epoch 5/30.. Train loss: 2.196.. Test loss: 2.004.. Test accuracy: 0.320
# Epoch 10/30.. Train loss: 1.549.. Test loss: 1.283.. Test accuracy: 0.573
# Epoch 15/30.. Train loss: 0.832.. Test loss: 0.796.. Test accuracy: 0.667
# Epoch 20/30.. Train loss: 0.454.. Test loss: 0.623.. Test accuracy: 0.787
# Epoch 25/30.. Train loss: 0.229.. Test loss: 0.610.. Test accuracy: 0.800
# Epoch 30/30.. Train loss: 0.100.. Test loss: 0.594.. Test accuracy: 0.847
# Training model: 36
# Epoch 5/30.. Train loss: 2.143.. Test loss: 1.964.. Test accuracy: 0.253
# Epoch 10/30.. Train loss: 1.491.. Test loss: 1.309.. Test accuracy: 0.620
# Epoch 15/30.. Train loss: 0.804.. Test loss: 0.864.. Test accuracy: 0.747
# Epoch 20/30.. Train loss: 0.397.. Test loss: 0.745.. Test accuracy: 0.793
# Epoch 25/30.. Train loss: 0.168.. Test loss: 0.752.. Test accuracy: 0.760
# Epoch 30/30.. Train loss: 0.059.. Test loss: 0.897.. Test accuracy: 0.780
# Training model: 37
# Epoch 5/30.. Train loss: 2.170.. Test loss: 1.990.. Test accuracy: 0.520
# Epoch 10/30.. Train loss: 1.582.. Test loss: 1.428.. Test accuracy: 0.513
# Epoch 15/30.. Train loss: 0.841.. Test loss: 1.022.. Test accuracy: 0.667
# Epoch 20/30.. Train loss: 0.348.. Test loss: 0.970.. Test accuracy: 0.700
# Epoch 25/30.. Train loss: 0.123.. Test loss: 0.949.. Test accuracy: 0.760
# Epoch 30/30.. Train loss: 0.040.. Test loss: 1.030.. Test accuracy: 0.773
# Training model: 38
# Epoch 5/30.. Train loss: 2.165.. Test loss: 1.892.. Test accuracy: 0.313
# Epoch 10/30.. Train loss: 1.478.. Test loss: 1.207.. Test accuracy: 0.600
# Epoch 15/30.. Train loss: 0.788.. Test loss: 0.916.. Test accuracy: 0.640
# Epoch 20/30.. Train loss: 0.398.. Test loss: 0.891.. Test accuracy: 0.707
# Epoch 25/30.. Train loss: 0.164.. Test loss: 1.096.. Test accuracy: 0.700
# Epoch 30/30.. Train loss: 0.054.. Test loss: 1.211.. Test accuracy: 0.713
# Training model: 39
# Epoch 5/30.. Train loss: 2.183.. Test loss: 2.241.. Test accuracy: 0.167
# Epoch 10/30.. Train loss: 1.688.. Test loss: 1.592.. Test accuracy: 0.540
# Epoch 15/30.. Train loss: 1.017.. Test loss: 1.217.. Test accuracy: 0.633
# Epoch 20/30.. Train loss: 0.496.. Test loss: 1.165.. Test accuracy: 0.700
# Epoch 25/30.. Train loss: 0.235.. Test loss: 1.283.. Test accuracy: 0.740
# Epoch 30/30.. Train loss: 0.088.. Test loss: 1.446.. Test accuracy: 0.720
# Training model: 40
# Epoch 5/30.. Train loss: 2.203.. Test loss: 2.018.. Test accuracy: 0.507
# Epoch 10/30.. Train loss: 1.659.. Test loss: 1.318.. Test accuracy: 0.607
# Epoch 15/30.. Train loss: 0.935.. Test loss: 0.820.. Test accuracy: 0.753
# Epoch 20/30.. Train loss: 0.452.. Test loss: 0.637.. Test accuracy: 0.780
# Epoch 25/30.. Train loss: 0.181.. Test loss: 0.574.. Test accuracy: 0.813
# Epoch 30/30.. Train loss: 0.056.. Test loss: 0.631.. Test accuracy: 0.813
# Training model: 41
# Epoch 5/30.. Train loss: 2.149.. Test loss: 1.993.. Test accuracy: 0.360
# Epoch 10/30.. Train loss: 1.550.. Test loss: 1.591.. Test accuracy: 0.480
# Epoch 15/30.. Train loss: 0.810.. Test loss: 1.210.. Test accuracy: 0.553
# Epoch 20/30.. Train loss: 0.331.. Test loss: 1.147.. Test accuracy: 0.647
# Epoch 25/30.. Train loss: 0.113.. Test loss: 1.321.. Test accuracy: 0.620
# Epoch 30/30.. Train loss: 0.028.. Test loss: 1.503.. Test accuracy: 0.667
# Training model: 42
# Epoch 5/30.. Train loss: 2.186.. Test loss: 2.029.. Test accuracy: 0.400
# Epoch 10/30.. Train loss: 1.551.. Test loss: 1.451.. Test accuracy: 0.540
# Epoch 15/30.. Train loss: 0.802.. Test loss: 1.148.. Test accuracy: 0.640
# Epoch 20/30.. Train loss: 0.341.. Test loss: 1.277.. Test accuracy: 0.687
# Epoch 25/30.. Train loss: 0.115.. Test loss: 1.609.. Test accuracy: 0.653
# Epoch 30/30.. Train loss: 0.030.. Test loss: 1.854.. Test accuracy: 0.673
# Training model: 43
# Epoch 5/30.. Train loss: 2.177.. Test loss: 1.969.. Test accuracy: 0.333
# Epoch 10/30.. Train loss: 1.534.. Test loss: 1.304.. Test accuracy: 0.560
# Epoch 15/30.. Train loss: 0.845.. Test loss: 0.959.. Test accuracy: 0.687
# Epoch 20/30.. Train loss: 0.463.. Test loss: 0.853.. Test accuracy: 0.720
# Epoch 25/30.. Train loss: 0.240.. Test loss: 0.858.. Test accuracy: 0.773
# Epoch 30/30.. Train loss: 0.108.. Test loss: 0.919.. Test accuracy: 0.767
# Training model: 44
# Epoch 5/30.. Train loss: 2.170.. Test loss: 2.005.. Test accuracy: 0.327
# Epoch 10/30.. Train loss: 1.451.. Test loss: 1.353.. Test accuracy: 0.580
# Epoch 15/30.. Train loss: 0.687.. Test loss: 0.872.. Test accuracy: 0.707
# Epoch 20/30.. Train loss: 0.326.. Test loss: 0.803.. Test accuracy: 0.713
# Epoch 25/30.. Train loss: 0.134.. Test loss: 0.891.. Test accuracy: 0.727
# Epoch 30/30.. Train loss: 0.050.. Test loss: 1.236.. Test accuracy: 0.707
# Training model: 45
# Epoch 5/30.. Train loss: 2.176.. Test loss: 1.955.. Test accuracy: 0.340
# Epoch 10/30.. Train loss: 1.554.. Test loss: 1.406.. Test accuracy: 0.500
# Epoch 15/30.. Train loss: 0.892.. Test loss: 0.965.. Test accuracy: 0.620
# Epoch 20/30.. Train loss: 0.472.. Test loss: 0.749.. Test accuracy: 0.680
# Epoch 25/30.. Train loss: 0.240.. Test loss: 0.699.. Test accuracy: 0.727
# Epoch 30/30.. Train loss: 0.101.. Test loss: 0.799.. Test accuracy: 0.740
# Training model: 46
# Epoch 5/30.. Train loss: 2.164.. Test loss: 2.025.. Test accuracy: 0.260
# Epoch 10/30.. Train loss: 1.456.. Test loss: 1.279.. Test accuracy: 0.627
# Epoch 15/30.. Train loss: 0.742.. Test loss: 0.873.. Test accuracy: 0.740
# Epoch 20/30.. Train loss: 0.371.. Test loss: 0.886.. Test accuracy: 0.667
# Epoch 25/30.. Train loss: 0.169.. Test loss: 0.839.. Test accuracy: 0.760
# Epoch 30/30.. Train loss: 0.067.. Test loss: 0.947.. Test accuracy: 0.707
# Training model: 47
# Epoch 5/30.. Train loss: 2.166.. Test loss: 2.055.. Test accuracy: 0.487
# Epoch 10/30.. Train loss: 1.477.. Test loss: 1.412.. Test accuracy: 0.553
# Epoch 15/30.. Train loss: 0.775.. Test loss: 1.073.. Test accuracy: 0.633
# Epoch 20/30.. Train loss: 0.367.. Test loss: 1.064.. Test accuracy: 0.667
# Epoch 25/30.. Train loss: 0.146.. Test loss: 1.292.. Test accuracy: 0.667
# Epoch 30/30.. Train loss: 0.051.. Test loss: 1.327.. Test accuracy: 0.680
# Training model: 48
# Epoch 5/30.. Train loss: 2.199.. Test loss: 2.085.. Test accuracy: 0.307
# Epoch 10/30.. Train loss: 1.597.. Test loss: 1.428.. Test accuracy: 0.513
# Epoch 15/30.. Train loss: 0.856.. Test loss: 1.059.. Test accuracy: 0.660
# Epoch 20/30.. Train loss: 0.423.. Test loss: 0.870.. Test accuracy: 0.720
# Epoch 25/30.. Train loss: 0.181.. Test loss: 0.838.. Test accuracy: 0.740
# Epoch 30/30.. Train loss: 0.065.. Test loss: 0.854.. Test accuracy: 0.780
# Training model: 49
# Epoch 5/30.. Train loss: 2.161.. Test loss: 2.132.. Test accuracy: 0.213
# Epoch 10/30.. Train loss: 1.638.. Test loss: 1.785.. Test accuracy: 0.333
# Epoch 15/30.. Train loss: 1.063.. Test loss: 1.540.. Test accuracy: 0.493
# Epoch 20/30.. Train loss: 0.558.. Test loss: 1.452.. Test accuracy: 0.533
# Epoch 25/30.. Train loss: 0.253.. Test loss: 1.653.. Test accuracy: 0.513
# Epoch 30/30.. Train loss: 0.094.. Test loss: 1.940.. Test accuracy: 0.520
# Training model: 50
# Epoch 5/30.. Train loss: 2.174.. Test loss: 1.992.. Test accuracy: 0.380
# Epoch 10/30.. Train loss: 1.549.. Test loss: 1.296.. Test accuracy: 0.593
# Epoch 15/30.. Train loss: 0.754.. Test loss: 0.877.. Test accuracy: 0.727
# Epoch 20/30.. Train loss: 0.272.. Test loss: 0.731.. Test accuracy: 0.787
# Epoch 25/30.. Train loss: 0.089.. Test loss: 0.765.. Test accuracy: 0.813
# Epoch 30/30.. Train loss: 0.027.. Test loss: 0.823.. Test accuracy: 0.813
# Training model: 51
# Epoch 5/30.. Train loss: 2.103.. Test loss: 1.955.. Test accuracy: 0.347
# Epoch 10/30.. Train loss: 1.367.. Test loss: 1.266.. Test accuracy: 0.573
# Epoch 15/30.. Train loss: 0.704.. Test loss: 0.818.. Test accuracy: 0.707
# Epoch 20/30.. Train loss: 0.299.. Test loss: 0.713.. Test accuracy: 0.787
# Epoch 25/30.. Train loss: 0.108.. Test loss: 0.803.. Test accuracy: 0.773
# Epoch 30/30.. Train loss: 0.031.. Test loss: 0.875.. Test accuracy: 0.753
# Training model: 52
# Epoch 5/30.. Train loss: 2.171.. Test loss: 2.019.. Test accuracy: 0.400
# Epoch 10/30.. Train loss: 1.588.. Test loss: 1.482.. Test accuracy: 0.513
# Epoch 15/30.. Train loss: 0.963.. Test loss: 1.053.. Test accuracy: 0.653
# Epoch 20/30.. Train loss: 0.503.. Test loss: 0.822.. Test accuracy: 0.733
# Epoch 25/30.. Train loss: 0.245.. Test loss: 0.796.. Test accuracy: 0.747
# Epoch 30/30.. Train loss: 0.110.. Test loss: 0.922.. Test accuracy: 0.760
# Training model: 53
# Epoch 5/30.. Train loss: 2.181.. Test loss: 1.956.. Test accuracy: 0.460
# Epoch 10/30.. Train loss: 1.555.. Test loss: 1.426.. Test accuracy: 0.560
# Epoch 15/30.. Train loss: 0.866.. Test loss: 1.121.. Test accuracy: 0.607
# Epoch 20/30.. Train loss: 0.422.. Test loss: 0.993.. Test accuracy: 0.687
# Epoch 25/30.. Train loss: 0.168.. Test loss: 0.993.. Test accuracy: 0.727
# Epoch 30/30.. Train loss: 0.057.. Test loss: 0.933.. Test accuracy: 0.780
# Training model: 54
# Epoch 5/30.. Train loss: 2.188.. Test loss: 1.981.. Test accuracy: 0.453
# Epoch 10/30.. Train loss: 1.560.. Test loss: 1.270.. Test accuracy: 0.593
# Epoch 15/30.. Train loss: 0.804.. Test loss: 0.916.. Test accuracy: 0.693
# Epoch 20/30.. Train loss: 0.394.. Test loss: 0.866.. Test accuracy: 0.760
# Epoch 25/30.. Train loss: 0.184.. Test loss: 0.865.. Test accuracy: 0.787
# Epoch 30/30.. Train loss: 0.067.. Test loss: 0.964.. Test accuracy: 0.800
# Training model: 55
# Epoch 5/30.. Train loss: 2.199.. Test loss: 2.215.. Test accuracy: 0.333
# Epoch 10/30.. Train loss: 1.655.. Test loss: 1.630.. Test accuracy: 0.433
# Epoch 15/30.. Train loss: 0.971.. Test loss: 1.131.. Test accuracy: 0.573
# Epoch 20/30.. Train loss: 0.558.. Test loss: 1.034.. Test accuracy: 0.627
# Epoch 25/30.. Train loss: 0.305.. Test loss: 0.958.. Test accuracy: 0.707
# Epoch 30/30.. Train loss: 0.131.. Test loss: 1.076.. Test accuracy: 0.727
# Training model: 56
# Epoch 5/30.. Train loss: 2.201.. Test loss: 2.124.. Test accuracy: 0.367
# Epoch 10/30.. Train loss: 1.653.. Test loss: 1.554.. Test accuracy: 0.513
# Epoch 15/30.. Train loss: 0.922.. Test loss: 1.122.. Test accuracy: 0.580
# Epoch 20/30.. Train loss: 0.446.. Test loss: 1.069.. Test accuracy: 0.653
# Epoch 25/30.. Train loss: 0.210.. Test loss: 1.272.. Test accuracy: 0.680
# Epoch 30/30.. Train loss: 0.082.. Test loss: 1.392.. Test accuracy: 0.687
# Training model: 57
# Epoch 5/30.. Train loss: 2.124.. Test loss: 2.039.. Test accuracy: 0.287
# Epoch 10/30.. Train loss: 1.505.. Test loss: 1.284.. Test accuracy: 0.607
# Epoch 15/30.. Train loss: 0.792.. Test loss: 0.938.. Test accuracy: 0.720
# Epoch 20/30.. Train loss: 0.343.. Test loss: 0.862.. Test accuracy: 0.773
# Epoch 25/30.. Train loss: 0.110.. Test loss: 1.029.. Test accuracy: 0.747
# Epoch 30/30.. Train loss: 0.028.. Test loss: 1.247.. Test accuracy: 0.753
# Training model: 58
# Epoch 5/30.. Train loss: 2.195.. Test loss: 2.126.. Test accuracy: 0.300
# Epoch 10/30.. Train loss: 1.597.. Test loss: 1.507.. Test accuracy: 0.553
# Epoch 15/30.. Train loss: 0.881.. Test loss: 1.201.. Test accuracy: 0.687
# Epoch 20/30.. Train loss: 0.475.. Test loss: 1.146.. Test accuracy: 0.693
# Epoch 25/30.. Train loss: 0.230.. Test loss: 1.136.. Test accuracy: 0.707
# Epoch 30/30.. Train loss: 0.094.. Test loss: 1.280.. Test accuracy: 0.693
# Training model: 59
# Epoch 5/30.. Train loss: 2.202.. Test loss: 2.008.. Test accuracy: 0.393
# Epoch 10/30.. Train loss: 1.577.. Test loss: 1.301.. Test accuracy: 0.687
# Epoch 15/30.. Train loss: 0.758.. Test loss: 1.007.. Test accuracy: 0.667
# Epoch 20/30.. Train loss: 0.337.. Test loss: 1.014.. Test accuracy: 0.680
# Epoch 25/30.. Train loss: 0.145.. Test loss: 1.040.. Test accuracy: 0.693
# Epoch 30/30.. Train loss: 0.060.. Test loss: 1.194.. Test accuracy: 0.713
# Training model: 60
# Epoch 5/30.. Train loss: 2.059.. Test loss: 1.778.. Test accuracy: 0.460
# Epoch 10/30.. Train loss: 1.217.. Test loss: 1.232.. Test accuracy: 0.673
# Epoch 15/30.. Train loss: 0.549.. Test loss: 0.987.. Test accuracy: 0.740
# Epoch 20/30.. Train loss: 0.223.. Test loss: 1.017.. Test accuracy: 0.753
# Epoch 25/30.. Train loss: 0.078.. Test loss: 1.210.. Test accuracy: 0.727
# Epoch 30/30.. Train loss: 0.022.. Test loss: 1.326.. Test accuracy: 0.740
# Training model: 61
# Epoch 5/30.. Train loss: 2.131.. Test loss: 1.859.. Test accuracy: 0.340
# Epoch 10/30.. Train loss: 1.375.. Test loss: 1.210.. Test accuracy: 0.613
# Epoch 15/30.. Train loss: 0.669.. Test loss: 0.778.. Test accuracy: 0.753
# Epoch 20/30.. Train loss: 0.306.. Test loss: 0.687.. Test accuracy: 0.773
# Epoch 25/30.. Train loss: 0.119.. Test loss: 0.768.. Test accuracy: 0.787
# Epoch 30/30.. Train loss: 0.039.. Test loss: 0.743.. Test accuracy: 0.827
# Training model: 62
# Epoch 5/30.. Train loss: 2.160.. Test loss: 2.002.. Test accuracy: 0.273
# Epoch 10/30.. Train loss: 1.476.. Test loss: 1.414.. Test accuracy: 0.493
# Epoch 15/30.. Train loss: 0.705.. Test loss: 0.989.. Test accuracy: 0.660
# Epoch 20/30.. Train loss: 0.278.. Test loss: 1.028.. Test accuracy: 0.687
# Epoch 25/30.. Train loss: 0.095.. Test loss: 1.239.. Test accuracy: 0.647
# Epoch 30/30.. Train loss: 0.029.. Test loss: 1.449.. Test accuracy: 0.667
# Training model: 63
# Epoch 5/30.. Train loss: 2.189.. Test loss: 2.103.. Test accuracy: 0.240
# Epoch 10/30.. Train loss: 1.652.. Test loss: 1.569.. Test accuracy: 0.433
# Epoch 15/30.. Train loss: 0.948.. Test loss: 1.124.. Test accuracy: 0.633
# Epoch 20/30.. Train loss: 0.442.. Test loss: 1.041.. Test accuracy: 0.653
# Epoch 25/30.. Train loss: 0.175.. Test loss: 1.149.. Test accuracy: 0.660
# Epoch 30/30.. Train loss: 0.062.. Test loss: 1.201.. Test accuracy: 0.687
# Training model: 64
# Epoch 5/30.. Train loss: 2.127.. Test loss: 1.903.. Test accuracy: 0.340
# Epoch 10/30.. Train loss: 1.333.. Test loss: 1.280.. Test accuracy: 0.593
# Epoch 15/30.. Train loss: 0.689.. Test loss: 0.929.. Test accuracy: 0.733
# Epoch 20/30.. Train loss: 0.336.. Test loss: 0.861.. Test accuracy: 0.747
# Epoch 25/30.. Train loss: 0.149.. Test loss: 0.918.. Test accuracy: 0.787
# Epoch 30/30.. Train loss: 0.062.. Test loss: 1.026.. Test accuracy: 0.760
# Training model: 65
# Epoch 5/30.. Train loss: 2.066.. Test loss: 1.854.. Test accuracy: 0.407
# Epoch 10/30.. Train loss: 1.182.. Test loss: 1.165.. Test accuracy: 0.633
# Epoch 15/30.. Train loss: 0.468.. Test loss: 1.085.. Test accuracy: 0.667
# Epoch 20/30.. Train loss: 0.173.. Test loss: 1.055.. Test accuracy: 0.700
# Epoch 25/30.. Train loss: 0.055.. Test loss: 1.363.. Test accuracy: 0.713
# Epoch 30/30.. Train loss: 0.017.. Test loss: 1.295.. Test accuracy: 0.767
# Training model: 66
# Epoch 5/30.. Train loss: 2.137.. Test loss: 1.814.. Test accuracy: 0.413
# Epoch 10/30.. Train loss: 1.392.. Test loss: 1.220.. Test accuracy: 0.647
# Epoch 15/30.. Train loss: 0.750.. Test loss: 0.811.. Test accuracy: 0.720
# Epoch 20/30.. Train loss: 0.371.. Test loss: 0.682.. Test accuracy: 0.787
# Epoch 25/30.. Train loss: 0.165.. Test loss: 0.726.. Test accuracy: 0.807
# Epoch 30/30.. Train loss: 0.061.. Test loss: 0.811.. Test accuracy: 0.793
# Training model: 67
# Epoch 5/30.. Train loss: 2.172.. Test loss: 2.005.. Test accuracy: 0.213
# Epoch 10/30.. Train loss: 1.546.. Test loss: 1.405.. Test accuracy: 0.560
# Epoch 15/30.. Train loss: 0.821.. Test loss: 1.035.. Test accuracy: 0.660
# Epoch 20/30.. Train loss: 0.367.. Test loss: 0.922.. Test accuracy: 0.727
# Epoch 25/30.. Train loss: 0.140.. Test loss: 1.029.. Test accuracy: 0.720
# Epoch 30/30.. Train loss: 0.043.. Test loss: 1.295.. Test accuracy: 0.693
# Training model: 68
# Epoch 5/30.. Train loss: 2.144.. Test loss: 1.884.. Test accuracy: 0.347
# Epoch 10/30.. Train loss: 1.445.. Test loss: 1.250.. Test accuracy: 0.540
# Epoch 15/30.. Train loss: 0.746.. Test loss: 0.817.. Test accuracy: 0.667
# Epoch 20/30.. Train loss: 0.377.. Test loss: 0.735.. Test accuracy: 0.753
# Epoch 25/30.. Train loss: 0.170.. Test loss: 0.680.. Test accuracy: 0.793
# Epoch 30/30.. Train loss: 0.065.. Test loss: 0.759.. Test accuracy: 0.780
# Training model: 69
# Epoch 5/30.. Train loss: 2.181.. Test loss: 1.971.. Test accuracy: 0.333
# Epoch 10/30.. Train loss: 1.525.. Test loss: 1.275.. Test accuracy: 0.667
# Epoch 15/30.. Train loss: 0.770.. Test loss: 0.888.. Test accuracy: 0.753
# Epoch 20/30.. Train loss: 0.316.. Test loss: 0.866.. Test accuracy: 0.753
# Epoch 25/30.. Train loss: 0.110.. Test loss: 1.188.. Test accuracy: 0.733
# Epoch 30/30.. Train loss: 0.028.. Test loss: 1.270.. Test accuracy: 0.753
# Training model: 70
# Epoch 5/30.. Train loss: 2.160.. Test loss: 1.873.. Test accuracy: 0.453
# Epoch 10/30.. Train loss: 1.368.. Test loss: 1.255.. Test accuracy: 0.620
# Epoch 15/30.. Train loss: 0.651.. Test loss: 0.829.. Test accuracy: 0.787
# Epoch 20/30.. Train loss: 0.259.. Test loss: 0.825.. Test accuracy: 0.807
# Epoch 25/30.. Train loss: 0.090.. Test loss: 1.024.. Test accuracy: 0.793
# Epoch 30/30.. Train loss: 0.032.. Test loss: 1.094.. Test accuracy: 0.773
# Training model: 71
# Epoch 5/30.. Train loss: 2.106.. Test loss: 1.822.. Test accuracy: 0.433
# Epoch 10/30.. Train loss: 1.296.. Test loss: 1.038.. Test accuracy: 0.653
# Epoch 15/30.. Train loss: 0.629.. Test loss: 0.736.. Test accuracy: 0.747
# Epoch 20/30.. Train loss: 0.281.. Test loss: 0.579.. Test accuracy: 0.827
# Epoch 25/30.. Train loss: 0.113.. Test loss: 0.686.. Test accuracy: 0.800
# Epoch 30/30.. Train loss: 0.041.. Test loss: 0.712.. Test accuracy: 0.820
# Training model: 72
# Epoch 5/30.. Train loss: 2.104.. Test loss: 1.968.. Test accuracy: 0.433
# Epoch 10/30.. Train loss: 1.287.. Test loss: 1.210.. Test accuracy: 0.620
# Epoch 15/30.. Train loss: 0.553.. Test loss: 0.870.. Test accuracy: 0.720
# Epoch 20/30.. Train loss: 0.203.. Test loss: 0.827.. Test accuracy: 0.753
# Epoch 25/30.. Train loss: 0.065.. Test loss: 0.900.. Test accuracy: 0.767
# Epoch 30/30.. Train loss: 0.018.. Test loss: 1.039.. Test accuracy: 0.787
# Training model: 73
# Epoch 5/30.. Train loss: 2.106.. Test loss: 1.995.. Test accuracy: 0.253
# Epoch 10/30.. Train loss: 1.331.. Test loss: 1.378.. Test accuracy: 0.467
# Epoch 15/30.. Train loss: 0.673.. Test loss: 0.987.. Test accuracy: 0.607
# Epoch 20/30.. Train loss: 0.299.. Test loss: 0.862.. Test accuracy: 0.707
# Epoch 25/30.. Train loss: 0.096.. Test loss: 1.101.. Test accuracy: 0.673
# Epoch 30/30.. Train loss: 0.027.. Test loss: 1.332.. Test accuracy: 0.707
# Training model: 74
# Epoch 5/30.. Train loss: 2.158.. Test loss: 1.978.. Test accuracy: 0.273
# Epoch 10/30.. Train loss: 1.741.. Test loss: 1.570.. Test accuracy: 0.587
# Epoch 15/30.. Train loss: 1.214.. Test loss: 1.163.. Test accuracy: 0.600
# Epoch 20/30.. Train loss: 0.710.. Test loss: 0.986.. Test accuracy: 0.653
# Epoch 25/30.. Train loss: 0.374.. Test loss: 0.851.. Test accuracy: 0.727
# Epoch 30/30.. Train loss: 0.156.. Test loss: 0.808.. Test accuracy: 0.807
# Training model: 75
# Epoch 5/30.. Train loss: 2.148.. Test loss: 1.965.. Test accuracy: 0.253
# Epoch 10/30.. Train loss: 1.448.. Test loss: 1.466.. Test accuracy: 0.573
# Epoch 15/30.. Train loss: 0.698.. Test loss: 1.214.. Test accuracy: 0.587
# Epoch 20/30.. Train loss: 0.293.. Test loss: 1.149.. Test accuracy: 0.633
# Epoch 25/30.. Train loss: 0.099.. Test loss: 1.334.. Test accuracy: 0.667
# Epoch 30/30.. Train loss: 0.029.. Test loss: 1.556.. Test accuracy: 0.680
# Training model: 76
# Epoch 5/30.. Train loss: 2.140.. Test loss: 1.990.. Test accuracy: 0.280
# Epoch 10/30.. Train loss: 1.359.. Test loss: 1.177.. Test accuracy: 0.633
# Epoch 15/30.. Train loss: 0.587.. Test loss: 0.680.. Test accuracy: 0.773
# Epoch 20/30.. Train loss: 0.220.. Test loss: 0.641.. Test accuracy: 0.807
# Epoch 25/30.. Train loss: 0.075.. Test loss: 0.798.. Test accuracy: 0.813
# Epoch 30/30.. Train loss: 0.020.. Test loss: 0.726.. Test accuracy: 0.820
# Training model: 77
# Epoch 5/30.. Train loss: 2.106.. Test loss: 1.877.. Test accuracy: 0.353
# Epoch 10/30.. Train loss: 1.331.. Test loss: 1.260.. Test accuracy: 0.553
# Epoch 15/30.. Train loss: 0.598.. Test loss: 0.992.. Test accuracy: 0.673
# Epoch 20/30.. Train loss: 0.247.. Test loss: 0.997.. Test accuracy: 0.680
# Epoch 25/30.. Train loss: 0.098.. Test loss: 1.124.. Test accuracy: 0.727
# Epoch 30/30.. Train loss: 0.033.. Test loss: 1.312.. Test accuracy: 0.733
# Training model: 78
# Epoch 5/30.. Train loss: 2.215.. Test loss: 2.081.. Test accuracy: 0.107
# Epoch 10/30.. Train loss: 1.729.. Test loss: 1.463.. Test accuracy: 0.567
# Epoch 15/30.. Train loss: 0.994.. Test loss: 1.083.. Test accuracy: 0.653
# Epoch 20/30.. Train loss: 0.509.. Test loss: 0.936.. Test accuracy: 0.707
# Epoch 25/30.. Train loss: 0.236.. Test loss: 1.071.. Test accuracy: 0.707
# Epoch 30/30.. Train loss: 0.092.. Test loss: 1.173.. Test accuracy: 0.707
# Training model: 79
# Epoch 5/30.. Train loss: 2.187.. Test loss: 2.076.. Test accuracy: 0.293
# Epoch 10/30.. Train loss: 1.548.. Test loss: 1.517.. Test accuracy: 0.500
# Epoch 15/30.. Train loss: 0.819.. Test loss: 1.239.. Test accuracy: 0.620
# Epoch 20/30.. Train loss: 0.451.. Test loss: 1.172.. Test accuracy: 0.687
# Epoch 25/30.. Train loss: 0.244.. Test loss: 1.309.. Test accuracy: 0.700
# Epoch 30/30.. Train loss: 0.104.. Test loss: 1.261.. Test accuracy: 0.753
# Training model: 80
# Epoch 5/30.. Train loss: 2.158.. Test loss: 1.986.. Test accuracy: 0.393
# Epoch 10/30.. Train loss: 1.532.. Test loss: 1.246.. Test accuracy: 0.600
# Epoch 15/30.. Train loss: 0.851.. Test loss: 0.917.. Test accuracy: 0.693
# Epoch 20/30.. Train loss: 0.488.. Test loss: 0.791.. Test accuracy: 0.727
# Epoch 25/30.. Train loss: 0.271.. Test loss: 0.783.. Test accuracy: 0.727
# Epoch 30/30.. Train loss: 0.133.. Test loss: 0.824.. Test accuracy: 0.720
# Training model: 81
# Epoch 5/30.. Train loss: 2.156.. Test loss: 2.041.. Test accuracy: 0.313
# Epoch 10/30.. Train loss: 1.414.. Test loss: 1.501.. Test accuracy: 0.553
# Epoch 15/30.. Train loss: 0.664.. Test loss: 1.232.. Test accuracy: 0.600
# Epoch 20/30.. Train loss: 0.266.. Test loss: 1.217.. Test accuracy: 0.633
# Epoch 25/30.. Train loss: 0.090.. Test loss: 1.318.. Test accuracy: 0.700
# Epoch 30/30.. Train loss: 0.031.. Test loss: 1.415.. Test accuracy: 0.693
# Training model: 82
# Epoch 5/30.. Train loss: 2.166.. Test loss: 1.973.. Test accuracy: 0.353
# Epoch 10/30.. Train loss: 1.583.. Test loss: 1.449.. Test accuracy: 0.573
# Epoch 15/30.. Train loss: 0.849.. Test loss: 1.096.. Test accuracy: 0.667
# Epoch 20/30.. Train loss: 0.382.. Test loss: 1.144.. Test accuracy: 0.693
# Epoch 25/30.. Train loss: 0.158.. Test loss: 1.185.. Test accuracy: 0.713
# Epoch 30/30.. Train loss: 0.061.. Test loss: 1.287.. Test accuracy: 0.673
# Training model: 83
# Epoch 5/30.. Train loss: 2.141.. Test loss: 2.049.. Test accuracy: 0.267
# Epoch 10/30.. Train loss: 1.395.. Test loss: 1.471.. Test accuracy: 0.553
# Epoch 15/30.. Train loss: 0.684.. Test loss: 1.096.. Test accuracy: 0.633
# Epoch 20/30.. Train loss: 0.356.. Test loss: 1.178.. Test accuracy: 0.633
# Epoch 25/30.. Train loss: 0.188.. Test loss: 1.429.. Test accuracy: 0.660
# Epoch 30/30.. Train loss: 0.094.. Test loss: 1.551.. Test accuracy: 0.660
# Training model: 84
# Epoch 5/30.. Train loss: 2.147.. Test loss: 1.980.. Test accuracy: 0.253
# Epoch 10/30.. Train loss: 1.349.. Test loss: 1.386.. Test accuracy: 0.573
# Epoch 15/30.. Train loss: 0.635.. Test loss: 1.160.. Test accuracy: 0.620
# Epoch 20/30.. Train loss: 0.304.. Test loss: 1.181.. Test accuracy: 0.680
# Epoch 25/30.. Train loss: 0.133.. Test loss: 1.299.. Test accuracy: 0.700
# Epoch 30/30.. Train loss: 0.049.. Test loss: 1.624.. Test accuracy: 0.673
# Training model: 85
# Epoch 5/30.. Train loss: 2.133.. Test loss: 2.015.. Test accuracy: 0.280
# Epoch 10/30.. Train loss: 1.431.. Test loss: 1.243.. Test accuracy: 0.553
# Epoch 15/30.. Train loss: 0.680.. Test loss: 0.792.. Test accuracy: 0.773
# Epoch 20/30.. Train loss: 0.289.. Test loss: 0.690.. Test accuracy: 0.813
# Epoch 25/30.. Train loss: 0.105.. Test loss: 0.771.. Test accuracy: 0.820
# Epoch 30/30.. Train loss: 0.038.. Test loss: 0.832.. Test accuracy: 0.800
# Training model: 86
# Epoch 5/30.. Train loss: 2.124.. Test loss: 2.013.. Test accuracy: 0.313
# Epoch 10/30.. Train loss: 1.421.. Test loss: 1.383.. Test accuracy: 0.533
# Epoch 15/30.. Train loss: 0.692.. Test loss: 0.942.. Test accuracy: 0.687
# Epoch 20/30.. Train loss: 0.279.. Test loss: 0.743.. Test accuracy: 0.753
# Epoch 25/30.. Train loss: 0.088.. Test loss: 0.742.. Test accuracy: 0.773
# Epoch 30/30.. Train loss: 0.024.. Test loss: 0.886.. Test accuracy: 0.760
# Training model: 87
# Epoch 5/30.. Train loss: 2.203.. Test loss: 2.002.. Test accuracy: 0.293
# Epoch 10/30.. Train loss: 1.649.. Test loss: 1.442.. Test accuracy: 0.520
# Epoch 15/30.. Train loss: 0.968.. Test loss: 0.937.. Test accuracy: 0.713
# Epoch 20/30.. Train loss: 0.533.. Test loss: 0.742.. Test accuracy: 0.760
# Epoch 25/30.. Train loss: 0.263.. Test loss: 0.776.. Test accuracy: 0.753
# Epoch 30/30.. Train loss: 0.113.. Test loss: 1.007.. Test accuracy: 0.727
# Training model: 88
# Epoch 5/30.. Train loss: 2.221.. Test loss: 2.040.. Test accuracy: 0.280
# Epoch 10/30.. Train loss: 1.662.. Test loss: 1.358.. Test accuracy: 0.593
# Epoch 15/30.. Train loss: 0.862.. Test loss: 1.004.. Test accuracy: 0.707
# Epoch 20/30.. Train loss: 0.450.. Test loss: 1.042.. Test accuracy: 0.760
# Epoch 25/30.. Train loss: 0.237.. Test loss: 1.131.. Test accuracy: 0.747
# Epoch 30/30.. Train loss: 0.109.. Test loss: 1.282.. Test accuracy: 0.760
# Training model: 89
# Epoch 5/30.. Train loss: 2.190.. Test loss: 1.978.. Test accuracy: 0.360
# Epoch 10/30.. Train loss: 1.565.. Test loss: 1.322.. Test accuracy: 0.560
# Epoch 15/30.. Train loss: 0.922.. Test loss: 0.974.. Test accuracy: 0.660
# Epoch 20/30.. Train loss: 0.511.. Test loss: 1.036.. Test accuracy: 0.653
# Epoch 25/30.. Train loss: 0.260.. Test loss: 1.050.. Test accuracy: 0.740
# Epoch 30/30.. Train loss: 0.110.. Test loss: 1.074.. Test accuracy: 0.740
# Training model: 90
# Epoch 5/30.. Train loss: 2.146.. Test loss: 1.885.. Test accuracy: 0.480
# Epoch 10/30.. Train loss: 1.318.. Test loss: 1.123.. Test accuracy: 0.647
# Epoch 15/30.. Train loss: 0.622.. Test loss: 0.850.. Test accuracy: 0.733
# Epoch 20/30.. Train loss: 0.299.. Test loss: 0.844.. Test accuracy: 0.720
# Epoch 25/30.. Train loss: 0.129.. Test loss: 0.784.. Test accuracy: 0.767
# Epoch 30/30.. Train loss: 0.049.. Test loss: 0.883.. Test accuracy: 0.767
# Training model: 91
# Epoch 5/30.. Train loss: 2.208.. Test loss: 2.095.. Test accuracy: 0.327
# Epoch 10/30.. Train loss: 1.638.. Test loss: 1.369.. Test accuracy: 0.613
# Epoch 15/30.. Train loss: 0.881.. Test loss: 0.907.. Test accuracy: 0.760
# Epoch 20/30.. Train loss: 0.421.. Test loss: 0.872.. Test accuracy: 0.753
# Epoch 25/30.. Train loss: 0.169.. Test loss: 0.891.. Test accuracy: 0.780
# Epoch 30/30.. Train loss: 0.056.. Test loss: 0.935.. Test accuracy: 0.800
# Training model: 92
# Epoch 5/30.. Train loss: 2.158.. Test loss: 2.002.. Test accuracy: 0.427
# Epoch 10/30.. Train loss: 1.464.. Test loss: 1.270.. Test accuracy: 0.647
# Epoch 15/30.. Train loss: 0.661.. Test loss: 0.937.. Test accuracy: 0.673
# Epoch 20/30.. Train loss: 0.284.. Test loss: 0.942.. Test accuracy: 0.713
# Epoch 25/30.. Train loss: 0.097.. Test loss: 0.981.. Test accuracy: 0.767
# Epoch 30/30.. Train loss: 0.027.. Test loss: 1.124.. Test accuracy: 0.740
# Training model: 93
# Epoch 5/30.. Train loss: 2.158.. Test loss: 1.949.. Test accuracy: 0.420
# Epoch 10/30.. Train loss: 1.474.. Test loss: 1.288.. Test accuracy: 0.553
# Epoch 15/30.. Train loss: 0.740.. Test loss: 0.726.. Test accuracy: 0.787
# Epoch 20/30.. Train loss: 0.288.. Test loss: 0.644.. Test accuracy: 0.773
# Epoch 25/30.. Train loss: 0.088.. Test loss: 0.667.. Test accuracy: 0.820
# Epoch 30/30.. Train loss: 0.022.. Test loss: 0.782.. Test accuracy: 0.800
# Training model: 94
# Epoch 5/30.. Train loss: 2.095.. Test loss: 1.799.. Test accuracy: 0.400
# Epoch 10/30.. Train loss: 1.231.. Test loss: 1.405.. Test accuracy: 0.513
# Epoch 15/30.. Train loss: 0.622.. Test loss: 1.234.. Test accuracy: 0.687
# Epoch 20/30.. Train loss: 0.315.. Test loss: 1.402.. Test accuracy: 0.740
# Epoch 25/30.. Train loss: 0.133.. Test loss: 1.479.. Test accuracy: 0.740
# Epoch 30/30.. Train loss: 0.046.. Test loss: 1.668.. Test accuracy: 0.733
# Training model: 95
# Epoch 5/30.. Train loss: 2.172.. Test loss: 1.986.. Test accuracy: 0.340
# Epoch 10/30.. Train loss: 1.408.. Test loss: 1.504.. Test accuracy: 0.453
# Epoch 15/30.. Train loss: 0.672.. Test loss: 1.165.. Test accuracy: 0.613
# Epoch 20/30.. Train loss: 0.290.. Test loss: 1.108.. Test accuracy: 0.727
# Epoch 25/30.. Train loss: 0.114.. Test loss: 1.245.. Test accuracy: 0.713
# Epoch 30/30.. Train loss: 0.034.. Test loss: 1.393.. Test accuracy: 0.713
# Training model: 96
# Epoch 5/30.. Train loss: 2.162.. Test loss: 1.843.. Test accuracy: 0.467
# Epoch 10/30.. Train loss: 1.388.. Test loss: 1.235.. Test accuracy: 0.587
# Epoch 15/30.. Train loss: 0.729.. Test loss: 0.825.. Test accuracy: 0.700
# Epoch 20/30.. Train loss: 0.344.. Test loss: 0.747.. Test accuracy: 0.773
# Epoch 25/30.. Train loss: 0.153.. Test loss: 0.813.. Test accuracy: 0.793
# Epoch 30/30.. Train loss: 0.067.. Test loss: 0.803.. Test accuracy: 0.807
# Training model: 97
# Epoch 5/30.. Train loss: 2.121.. Test loss: 1.984.. Test accuracy: 0.313
# Epoch 10/30.. Train loss: 1.274.. Test loss: 1.471.. Test accuracy: 0.500
# Epoch 15/30.. Train loss: 0.591.. Test loss: 1.469.. Test accuracy: 0.567
# Epoch 20/30.. Train loss: 0.260.. Test loss: 1.710.. Test accuracy: 0.593
# Epoch 25/30.. Train loss: 0.090.. Test loss: 1.938.. Test accuracy: 0.593
# Epoch 30/30.. Train loss: 0.026.. Test loss: 2.461.. Test accuracy: 0.600
# Training model: 98
# Epoch 5/30.. Train loss: 2.202.. Test loss: 1.994.. Test accuracy: 0.400
# Epoch 10/30.. Train loss: 1.650.. Test loss: 1.400.. Test accuracy: 0.620
# Epoch 15/30.. Train loss: 0.910.. Test loss: 0.968.. Test accuracy: 0.707
# Epoch 20/30.. Train loss: 0.439.. Test loss: 0.914.. Test accuracy: 0.713
# Epoch 25/30.. Train loss: 0.210.. Test loss: 1.157.. Test accuracy: 0.713
# Epoch 30/30.. Train loss: 0.098.. Test loss: 1.177.. Test accuracy: 0.733
# Training model: 99
# Epoch 5/30.. Train loss: 2.200.. Test loss: 2.071.. Test accuracy: 0.200
# Epoch 10/30.. Train loss: 1.681.. Test loss: 1.526.. Test accuracy: 0.453
# Epoch 15/30.. Train loss: 1.004.. Test loss: 1.152.. Test accuracy: 0.647
# Epoch 20/30.. Train loss: 0.549.. Test loss: 1.077.. Test accuracy: 0.633
# Epoch 25/30.. Train loss: 0.288.. Test loss: 1.132.. Test accuracy: 0.660
# Epoch 30/30.. Train loss: 0.126.. Test loss: 1.176.. Test accuracy: 0.693
# Training model: 100
# Epoch 5/30.. Train loss: 2.193.. Test loss: 2.210.. Test accuracy: 0.260
# Epoch 10/30.. Train loss: 1.574.. Test loss: 1.684.. Test accuracy: 0.533
# Epoch 15/30.. Train loss: 0.836.. Test loss: 1.305.. Test accuracy: 0.567
# Epoch 20/30.. Train loss: 0.413.. Test loss: 1.187.. Test accuracy: 0.660
# Epoch 25/30.. Train loss: 0.175.. Test loss: 1.193.. Test accuracy: 0.707
# Epoch 30/30.. Train loss: 0.058.. Test loss: 1.377.. Test accuracy: 0.713
# Training model: 101
# Epoch 5/30.. Train loss: 2.176.. Test loss: 1.970.. Test accuracy: 0.400
# Epoch 10/30.. Train loss: 1.559.. Test loss: 1.338.. Test accuracy: 0.553
# Epoch 15/30.. Train loss: 0.908.. Test loss: 0.968.. Test accuracy: 0.667
# Epoch 20/30.. Train loss: 0.475.. Test loss: 0.913.. Test accuracy: 0.707
# Epoch 25/30.. Train loss: 0.226.. Test loss: 0.847.. Test accuracy: 0.733
# Epoch 30/30.. Train loss: 0.095.. Test loss: 0.971.. Test accuracy: 0.720
# Training model: 102
# Epoch 5/30.. Train loss: 2.185.. Test loss: 2.136.. Test accuracy: 0.373
# Epoch 10/30.. Train loss: 1.641.. Test loss: 1.551.. Test accuracy: 0.440
# Epoch 15/30.. Train loss: 0.884.. Test loss: 1.217.. Test accuracy: 0.587
# Epoch 20/30.. Train loss: 0.439.. Test loss: 1.060.. Test accuracy: 0.673
# Epoch 25/30.. Train loss: 0.225.. Test loss: 1.200.. Test accuracy: 0.680
# Epoch 30/30.. Train loss: 0.108.. Test loss: 1.256.. Test accuracy: 0.700
# Training model: 103
# Epoch 5/30.. Train loss: 2.152.. Test loss: 1.996.. Test accuracy: 0.233
# Epoch 10/30.. Train loss: 1.464.. Test loss: 1.484.. Test accuracy: 0.487
# Epoch 15/30.. Train loss: 0.782.. Test loss: 1.158.. Test accuracy: 0.673
# Epoch 20/30.. Train loss: 0.375.. Test loss: 1.124.. Test accuracy: 0.667
# Epoch 25/30.. Train loss: 0.137.. Test loss: 1.324.. Test accuracy: 0.660
# ...
# Epoch 20/30.. Train loss: 0.424.. Test loss: 1.277.. Test accuracy: 0.660
# Epoch 25/30.. Train loss: 0.194.. Test loss: 1.483.. Test accuracy: 0.673
# Epoch 30/30.. Train loss: 0.081.. Test loss: 1.950.. Test accuracy: 0.667
# Training model: 166
# Epoch 5/30.. Train loss: 2.187.. Test loss: 1.954.. Test accuracy: 0.507
# Epoch 10/30.. Train loss: 1.566.. Test loss: 1.242.. Test accuracy: 0.520
# Epoch 15/30.. Train loss: 0.837.. Test loss: 0.770.. Test accuracy: 0.720
# Epoch 20/30.. Train loss: 0.412.. Test loss: 0.777.. Test accuracy: 0.747
# Epoch 25/30.. Train loss: 0.183.. Test loss: 0.953.. Test accuracy: 0.733
# Epoch 30/30.. Train loss: 0.063.. Test loss: 1.182.. Test accuracy: 0.740
# Training model: 167
# Epoch 5/30.. Train loss: 2.160.. Test loss: 1.985.. Test accuracy: 0.393
# Epoch 10/30.. Train loss: 1.525.. Test loss: 1.260.. Test accuracy: 0.667
# Epoch 15/30.. Train loss: 0.799.. Test loss: 0.847.. Test accuracy: 0.727
# Epoch 20/30.. Train loss: 0.404.. Test loss: 0.795.. Test accuracy: 0.820
# Epoch 25/30.. Train loss: 0.183.. Test loss: 1.040.. Test accuracy: 0.760
# Epoch 30/30.. Train loss: 0.072.. Test loss: 1.258.. Test accuracy: 0.753
# Training model: 168
# Epoch 5/30.. Train loss: 2.174.. Test loss: 2.114.. Test accuracy: 0.187
# Epoch 10/30.. Train loss: 1.528.. Test loss: 1.609.. Test accuracy: 0.460
# Epoch 15/30.. Train loss: 0.783.. Test loss: 1.309.. Test accuracy: 0.567
# Epoch 20/30.. Train loss: 0.415.. Test loss: 1.423.. Test accuracy: 0.640
# Epoch 25/30.. Train loss: 0.196.. Test loss: 1.365.. Test accuracy: 0.633
# Epoch 30/30.. Train loss: 0.079.. Test loss: 1.631.. Test accuracy: 0.593
# Training model: 169
# Epoch 5/30.. Train loss: 2.174.. Test loss: 2.022.. Test accuracy: 0.273
# Epoch 10/30.. Train loss: 1.474.. Test loss: 1.309.. Test accuracy: 0.593
# Epoch 15/30.. Train loss: 0.638.. Test loss: 1.072.. Test accuracy: 0.680
# Epoch 20/30.. Train loss: 0.224.. Test loss: 1.117.. Test accuracy: 0.747
# Epoch 25/30.. Train loss: 0.064.. Test loss: 1.315.. Test accuracy: 0.753
# Epoch 30/30.. Train loss: 0.020.. Test loss: 1.589.. Test accuracy: 0.753
# Training model: 170
# Epoch 5/30.. Train loss: 2.157.. Test loss: 1.962.. Test accuracy: 0.380
# Epoch 10/30.. Train loss: 1.465.. Test loss: 1.307.. Test accuracy: 0.633
# Epoch 15/30.. Train loss: 0.770.. Test loss: 1.083.. Test accuracy: 0.627
# Epoch 20/30.. Train loss: 0.394.. Test loss: 0.813.. Test accuracy: 0.727
# Epoch 25/30.. Train loss: 0.180.. Test loss: 0.783.. Test accuracy: 0.747
# Epoch 30/30.. Train loss: 0.068.. Test loss: 0.904.. Test accuracy: 0.740
# Training model: 171
# Epoch 5/30.. Train loss: 2.117.. Test loss: 2.155.. Test accuracy: 0.273
# Epoch 10/30.. Train loss: 1.391.. Test loss: 1.376.. Test accuracy: 0.600
# Epoch 15/30.. Train loss: 0.623.. Test loss: 1.067.. Test accuracy: 0.653
# Epoch 20/30.. Train loss: 0.245.. Test loss: 1.137.. Test accuracy: 0.707
# Epoch 25/30.. Train loss: 0.085.. Test loss: 1.217.. Test accuracy: 0.740
# Epoch 30/30.. Train loss: 0.021.. Test loss: 1.350.. Test accuracy: 0.780
# Training model: 172
# Epoch 5/30.. Train loss: 2.155.. Test loss: 2.071.. Test accuracy: 0.373
# Epoch 10/30.. Train loss: 1.495.. Test loss: 1.431.. Test accuracy: 0.620
# Epoch 15/30.. Train loss: 0.771.. Test loss: 0.802.. Test accuracy: 0.767
# Epoch 20/30.. Train loss: 0.291.. Test loss: 0.604.. Test accuracy: 0.780
# Epoch 25/30.. Train loss: 0.101.. Test loss: 0.662.. Test accuracy: 0.800
# Epoch 30/30.. Train loss: 0.034.. Test loss: 0.775.. Test accuracy: 0.793
# Training model: 173
# Epoch 5/30.. Train loss: 2.172.. Test loss: 2.013.. Test accuracy: 0.320
# Epoch 10/30.. Train loss: 1.588.. Test loss: 1.421.. Test accuracy: 0.553
# Epoch 15/30.. Train loss: 0.897.. Test loss: 1.265.. Test accuracy: 0.540
# Epoch 20/30.. Train loss: 0.478.. Test loss: 1.088.. Test accuracy: 0.680
# Epoch 25/30.. Train loss: 0.214.. Test loss: 0.991.. Test accuracy: 0.707
# Epoch 30/30.. Train loss: 0.079.. Test loss: 1.096.. Test accuracy: 0.740
# Training model: 174
# Epoch 5/30.. Train loss: 2.139.. Test loss: 2.019.. Test accuracy: 0.213
# Epoch 10/30.. Train loss: 1.453.. Test loss: 1.484.. Test accuracy: 0.480
# Epoch 15/30.. Train loss: 0.766.. Test loss: 1.107.. Test accuracy: 0.633
# Epoch 20/30.. Train loss: 0.345.. Test loss: 0.845.. Test accuracy: 0.700
# Epoch 25/30.. Train loss: 0.133.. Test loss: 0.743.. Test accuracy: 0.773
# Epoch 30/30.. Train loss: 0.044.. Test loss: 0.831.. Test accuracy: 0.787
# Training model: 175
# Epoch 5/30.. Train loss: 2.207.. Test loss: 2.024.. Test accuracy: 0.367
# Epoch 10/30.. Train loss: 1.649.. Test loss: 1.332.. Test accuracy: 0.547
# Epoch 15/30.. Train loss: 0.862.. Test loss: 0.910.. Test accuracy: 0.707
# Epoch 20/30.. Train loss: 0.405.. Test loss: 0.862.. Test accuracy: 0.740
# Epoch 25/30.. Train loss: 0.170.. Test loss: 0.904.. Test accuracy: 0.753
# Epoch 30/30.. Train loss: 0.059.. Test loss: 1.078.. Test accuracy: 0.740
# Training model: 176
# Epoch 5/30.. Train loss: 2.170.. Test loss: 2.009.. Test accuracy: 0.447
# Epoch 10/30.. Train loss: 1.548.. Test loss: 1.615.. Test accuracy: 0.507
# Epoch 15/30.. Train loss: 0.852.. Test loss: 1.305.. Test accuracy: 0.573
# Epoch 20/30.. Train loss: 0.415.. Test loss: 1.283.. Test accuracy: 0.607
# Epoch 25/30.. Train loss: 0.198.. Test loss: 1.461.. Test accuracy: 0.640
# Epoch 30/30.. Train loss: 0.077.. Test loss: 1.732.. Test accuracy: 0.627
# Training model: 177
# Epoch 5/30.. Train loss: 2.154.. Test loss: 2.105.. Test accuracy: 0.293
# Epoch 10/30.. Train loss: 1.487.. Test loss: 1.575.. Test accuracy: 0.467
# Epoch 15/30.. Train loss: 0.811.. Test loss: 1.272.. Test accuracy: 0.640
# Epoch 20/30.. Train loss: 0.365.. Test loss: 1.248.. Test accuracy: 0.727
# Epoch 25/30.. Train loss: 0.147.. Test loss: 1.291.. Test accuracy: 0.713
# Epoch 30/30.. Train loss: 0.048.. Test loss: 1.357.. Test accuracy: 0.740
# Training model: 178
# Epoch 5/30.. Train loss: 2.169.. Test loss: 1.964.. Test accuracy: 0.293
# Epoch 10/30.. Train loss: 1.574.. Test loss: 1.318.. Test accuracy: 0.620
# Epoch 15/30.. Train loss: 0.859.. Test loss: 0.833.. Test accuracy: 0.733
# Epoch 20/30.. Train loss: 0.402.. Test loss: 0.722.. Test accuracy: 0.740
# Epoch 25/30.. Train loss: 0.175.. Test loss: 0.743.. Test accuracy: 0.780
# Epoch 30/30.. Train loss: 0.056.. Test loss: 0.820.. Test accuracy: 0.780
# Training model: 179
# Epoch 5/30.. Train loss: 2.179.. Test loss: 2.007.. Test accuracy: 0.247
# Epoch 10/30.. Train loss: 1.637.. Test loss: 1.337.. Test accuracy: 0.747
# Epoch 15/30.. Train loss: 0.954.. Test loss: 0.798.. Test accuracy: 0.807
# Epoch 20/30.. Train loss: 0.472.. Test loss: 0.611.. Test accuracy: 0.800
# Epoch 25/30.. Train loss: 0.214.. Test loss: 0.563.. Test accuracy: 0.860
# Epoch 30/30.. Train loss: 0.089.. Test loss: 0.663.. Test accuracy: 0.847
# Training model: 180
# Epoch 5/30.. Train loss: 2.214.. Test loss: 2.074.. Test accuracy: 0.340
# Epoch 10/30.. Train loss: 1.616.. Test loss: 1.458.. Test accuracy: 0.527
# Epoch 15/30.. Train loss: 0.838.. Test loss: 1.150.. Test accuracy: 0.567
# Epoch 20/30.. Train loss: 0.405.. Test loss: 1.053.. Test accuracy: 0.687
# Epoch 25/30.. Train loss: 0.174.. Test loss: 1.314.. Test accuracy: 0.673
# Epoch 30/30.. Train loss: 0.057.. Test loss: 1.470.. Test accuracy: 0.673
# Training model: 181
# Epoch 5/30.. Train loss: 2.185.. Test loss: 1.946.. Test accuracy: 0.527
# Epoch 10/30.. Train loss: 1.494.. Test loss: 1.126.. Test accuracy: 0.640
# Epoch 15/30.. Train loss: 0.727.. Test loss: 0.692.. Test accuracy: 0.733
# Epoch 20/30.. Train loss: 0.399.. Test loss: 0.638.. Test accuracy: 0.833
# Epoch 25/30.. Train loss: 0.206.. Test loss: 0.597.. Test accuracy: 0.840
# Epoch 30/30.. Train loss: 0.105.. Test loss: 0.812.. Test accuracy: 0.767
# Training model: 182
# Epoch 5/30.. Train loss: 2.129.. Test loss: 2.022.. Test accuracy: 0.240
# Epoch 10/30.. Train loss: 1.537.. Test loss: 1.422.. Test accuracy: 0.493
# Epoch 15/30.. Train loss: 0.906.. Test loss: 0.825.. Test accuracy: 0.727
# Epoch 20/30.. Train loss: 0.463.. Test loss: 0.648.. Test accuracy: 0.787
# Epoch 25/30.. Train loss: 0.210.. Test loss: 0.619.. Test accuracy: 0.820
# Epoch 30/30.. Train loss: 0.080.. Test loss: 0.646.. Test accuracy: 0.767
# Training model: 183
# Epoch 5/30.. Train loss: 2.205.. Test loss: 2.164.. Test accuracy: 0.220
# Epoch 10/30.. Train loss: 1.626.. Test loss: 1.604.. Test accuracy: 0.460
# Epoch 15/30.. Train loss: 0.849.. Test loss: 1.151.. Test accuracy: 0.593
# Epoch 20/30.. Train loss: 0.363.. Test loss: 1.126.. Test accuracy: 0.620
# Epoch 25/30.. Train loss: 0.139.. Test loss: 1.253.. Test accuracy: 0.667
# Epoch 30/30.. Train loss: 0.047.. Test loss: 1.577.. Test accuracy: 0.660
# Training model: 184
# Epoch 5/30.. Train loss: 2.188.. Test loss: 2.013.. Test accuracy: 0.467
# Epoch 10/30.. Train loss: 1.566.. Test loss: 1.303.. Test accuracy: 0.607
# Epoch 15/30.. Train loss: 0.761.. Test loss: 0.866.. Test accuracy: 0.693
# Epoch 20/30.. Train loss: 0.320.. Test loss: 0.799.. Test accuracy: 0.780
# Epoch 25/30.. Train loss: 0.122.. Test loss: 0.825.. Test accuracy: 0.767
# Epoch 30/30.. Train loss: 0.041.. Test loss: 0.908.. Test accuracy: 0.747
# Training model: 185
# Epoch 5/30.. Train loss: 2.136.. Test loss: 1.789.. Test accuracy: 0.387
# Epoch 10/30.. Train loss: 1.211.. Test loss: 0.936.. Test accuracy: 0.733
# Epoch 15/30.. Train loss: 0.455.. Test loss: 0.828.. Test accuracy: 0.727
# Epoch 20/30.. Train loss: 0.209.. Test loss: 0.824.. Test accuracy: 0.747
# Epoch 25/30.. Train loss: 0.077.. Test loss: 0.843.. Test accuracy: 0.767
# Epoch 30/30.. Train loss: 0.027.. Test loss: 0.861.. Test accuracy: 0.767
# Training model: 186
# Epoch 5/30.. Train loss: 2.152.. Test loss: 1.963.. Test accuracy: 0.327
# Epoch 10/30.. Train loss: 1.466.. Test loss: 1.223.. Test accuracy: 0.647
# Epoch 15/30.. Train loss: 0.695.. Test loss: 0.673.. Test accuracy: 0.780
# Epoch 20/30.. Train loss: 0.286.. Test loss: 0.555.. Test accuracy: 0.813
# Epoch 25/30.. Train loss: 0.107.. Test loss: 0.547.. Test accuracy: 0.853
# Epoch 30/30.. Train loss: 0.034.. Test loss: 0.611.. Test accuracy: 0.840
# Training model: 187
# Epoch 5/30.. Train loss: 2.189.. Test loss: 2.107.. Test accuracy: 0.240
# Epoch 10/30.. Train loss: 1.665.. Test loss: 1.594.. Test accuracy: 0.453
# Epoch 15/30.. Train loss: 0.934.. Test loss: 1.133.. Test accuracy: 0.573
# Epoch 20/30.. Train loss: 0.471.. Test loss: 1.004.. Test accuracy: 0.660
# Epoch 25/30.. Train loss: 0.197.. Test loss: 0.991.. Test accuracy: 0.720
# Epoch 30/30.. Train loss: 0.072.. Test loss: 1.059.. Test accuracy: 0.780
# Training model: 188
# Epoch 5/30.. Train loss: 2.141.. Test loss: 1.887.. Test accuracy: 0.333
# Epoch 10/30.. Train loss: 1.317.. Test loss: 1.089.. Test accuracy: 0.693
# Epoch 15/30.. Train loss: 0.595.. Test loss: 1.019.. Test accuracy: 0.647
# Epoch 20/30.. Train loss: 0.303.. Test loss: 0.898.. Test accuracy: 0.747
# Epoch 25/30.. Train loss: 0.135.. Test loss: 0.907.. Test accuracy: 0.773
# Epoch 30/30.. Train loss: 0.058.. Test loss: 0.838.. Test accuracy: 0.787
# Training model: 189
# Epoch 5/30.. Train loss: 2.116.. Test loss: 1.871.. Test accuracy: 0.407
# Epoch 10/30.. Train loss: 1.343.. Test loss: 1.049.. Test accuracy: 0.600
# Epoch 15/30.. Train loss: 0.605.. Test loss: 0.840.. Test accuracy: 0.713
# Epoch 20/30.. Train loss: 0.220.. Test loss: 0.760.. Test accuracy: 0.780
# Epoch 25/30.. Train loss: 0.059.. Test loss: 0.933.. Test accuracy: 0.760
# Epoch 30/30.. Train loss: 0.015.. Test loss: 1.098.. Test accuracy: 0.793
# Training model: 190
# Epoch 5/30.. Train loss: 2.185.. Test loss: 2.044.. Test accuracy: 0.240
# Epoch 10/30.. Train loss: 1.528.. Test loss: 1.435.. Test accuracy: 0.580
# Epoch 15/30.. Train loss: 0.780.. Test loss: 0.975.. Test accuracy: 0.727
# Epoch 20/30.. Train loss: 0.339.. Test loss: 0.882.. Test accuracy: 0.753
# Epoch 25/30.. Train loss: 0.124.. Test loss: 0.902.. Test accuracy: 0.760
# Epoch 30/30.. Train loss: 0.038.. Test loss: 1.035.. Test accuracy: 0.753
# Training model: 191
# Epoch 5/30.. Train loss: 2.174.. Test loss: 2.028.. Test accuracy: 0.253
# Epoch 10/30.. Train loss: 1.584.. Test loss: 1.431.. Test accuracy: 0.567
# Epoch 15/30.. Train loss: 0.875.. Test loss: 1.055.. Test accuracy: 0.627
# Epoch 20/30.. Train loss: 0.443.. Test loss: 1.018.. Test accuracy: 0.700
# Epoch 25/30.. Train loss: 0.218.. Test loss: 1.076.. Test accuracy: 0.680
# Epoch 30/30.. Train loss: 0.105.. Test loss: 1.234.. Test accuracy: 0.680
# Training model: 192
# Epoch 5/30.. Train loss: 2.187.. Test loss: 2.186.. Test accuracy: 0.200
# Epoch 10/30.. Train loss: 1.621.. Test loss: 1.643.. Test accuracy: 0.527
# Epoch 15/30.. Train loss: 0.858.. Test loss: 1.189.. Test accuracy: 0.653
# Epoch 20/30.. Train loss: 0.363.. Test loss: 1.042.. Test accuracy: 0.653
# Epoch 25/30.. Train loss: 0.130.. Test loss: 1.109.. Test accuracy: 0.687
# Epoch 30/30.. Train loss: 0.039.. Test loss: 1.359.. Test accuracy: 0.687
# Training model: 193
# Epoch 5/30.. Train loss: 2.174.. Test loss: 1.912.. Test accuracy: 0.467
# Epoch 10/30.. Train loss: 1.553.. Test loss: 1.277.. Test accuracy: 0.607
# Epoch 15/30.. Train loss: 0.861.. Test loss: 0.875.. Test accuracy: 0.733
# Epoch 20/30.. Train loss: 0.429.. Test loss: 0.639.. Test accuracy: 0.767
# Epoch 25/30.. Train loss: 0.183.. Test loss: 0.541.. Test accuracy: 0.800
# Epoch 30/30.. Train loss: 0.062.. Test loss: 0.629.. Test accuracy: 0.800
# Training model: 194
# Epoch 5/30.. Train loss: 2.164.. Test loss: 1.987.. Test accuracy: 0.427
# Epoch 10/30.. Train loss: 1.292.. Test loss: 1.416.. Test accuracy: 0.440
# Epoch 15/30.. Train loss: 0.509.. Test loss: 1.154.. Test accuracy: 0.660
# Epoch 20/30.. Train loss: 0.167.. Test loss: 1.089.. Test accuracy: 0.720
# Epoch 25/30.. Train loss: 0.041.. Test loss: 0.981.. Test accuracy: 0.773
# Epoch 30/30.. Train loss: 0.009.. Test loss: 1.210.. Test accuracy: 0.747
# Training model: 195
# Epoch 5/30.. Train loss: 2.183.. Test loss: 1.994.. Test accuracy: 0.340
# Epoch 10/30.. Train loss: 1.453.. Test loss: 1.264.. Test accuracy: 0.593
# Epoch 15/30.. Train loss: 0.599.. Test loss: 1.073.. Test accuracy: 0.713
# Epoch 20/30.. Train loss: 0.233.. Test loss: 1.266.. Test accuracy: 0.707
# Epoch 25/30.. Train loss: 0.077.. Test loss: 1.277.. Test accuracy: 0.727
# Epoch 30/30.. Train loss: 0.020.. Test loss: 1.313.. Test accuracy: 0.733
# Training model: 196
# Epoch 5/30.. Train loss: 2.147.. Test loss: 2.003.. Test accuracy: 0.340
# Epoch 10/30.. Train loss: 1.296.. Test loss: 1.265.. Test accuracy: 0.613
# Epoch 15/30.. Train loss: 0.437.. Test loss: 0.880.. Test accuracy: 0.680
# Epoch 20/30.. Train loss: 0.124.. Test loss: 1.146.. Test accuracy: 0.627
# Epoch 25/30.. Train loss: 0.031.. Test loss: 1.193.. Test accuracy: 0.673
# Epoch 30/30.. Train loss: 0.009.. Test loss: 1.367.. Test accuracy: 0.640
# Training model: 197
# Epoch 5/30.. Train loss: 2.121.. Test loss: 1.853.. Test accuracy: 0.460
# Epoch 10/30.. Train loss: 1.280.. Test loss: 1.140.. Test accuracy: 0.613
# Epoch 15/30.. Train loss: 0.444.. Test loss: 0.572.. Test accuracy: 0.827
# Epoch 20/30.. Train loss: 0.107.. Test loss: 0.455.. Test accuracy: 0.840
# Epoch 25/30.. Train loss: 0.018.. Test loss: 0.595.. Test accuracy: 0.833
# Epoch 30/30.. Train loss: 0.004.. Test loss: 0.525.. Test accuracy: 0.847
# Training model: 198
# Epoch 5/30.. Train loss: 2.151.. Test loss: 1.891.. Test accuracy: 0.640
# Epoch 10/30.. Train loss: 1.342.. Test loss: 1.202.. Test accuracy: 0.593
# Epoch 15/30.. Train loss: 0.496.. Test loss: 0.876.. Test accuracy: 0.740
# Epoch 20/30.. Train loss: 0.160.. Test loss: 0.898.. Test accuracy: 0.767
# Epoch 25/30.. Train loss: 0.047.. Test loss: 0.939.. Test accuracy: 0.780
# Epoch 30/30.. Train loss: 0.013.. Test loss: 1.161.. Test accuracy: 0.787
# Training model: 199
# Epoch 5/30.. Train loss: 2.129.. Test loss: 1.813.. Test accuracy: 0.520
# Epoch 10/30.. Train loss: 1.272.. Test loss: 1.092.. Test accuracy: 0.653
# Epoch 15/30.. Train loss: 0.520.. Test loss: 0.811.. Test accuracy: 0.740
# Epoch 20/30.. Train loss: 0.202.. Test loss: 0.812.. Test accuracy: 0.760
# Epoch 25/30.. Train loss: 0.077.. Test loss: 0.963.. Test accuracy: 0.793
# Epoch 30/30.. Train loss: 0.028.. Test loss: 0.963.. Test accuracy: 0.833

# %% [markdown]
# # Saving/Loading

# %% [markdown]
# Save model's parameters

# %%
all_points = []

for i in range(len(classifiers)):
    all_points += [classifiers[i].state_dict()]

checkpoint = {'classifiers_list': all_points,}
torch.save(checkpoint, 'checkpoints/teachers_checkpoint.pth') ###############################################	Save

# %% [markdown]
# Load model's parameters

# %%
class Teacher(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(784, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 64)
        self.fc4 = nn.Linear(64, 10)
        
    def forward(self, x):
        # make sure input tensor is flattened
        x = x.view(x.shape[0], -1)
        
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.log_softmax(self.fc4(x), dim=1)
        
        return x

classifiers = [None for _ in range(num_teachers)]
for i in range(num_teachers):
    classifiers[i] = Teacher()

checkpoint = torch.load('checkpoints/teachers_checkpoint.pth')
classifiers_list = checkpoint['classifiers_list']
for i in range(len(classifiers_list)):
    classifiers[i].load_state_dict(classifiers_list[i])

# %%
batch_size = 64

# %% [markdown]
# # PATE Analysis

# %%
teacher_preds = np.zeros((num_teachers, num_examples)).astype(int)
truths = np.zeros((num_examples)).astype(int)

# %%
student_train_loader = torch.utils.data.DataLoader(student_train, batch_size=batch_size)
student_test_loader = torch.utils.data.DataLoader(student_test, batch_size=batch_size)

# %% [markdown]
# Get teachers' predictions for 2048 samples in student_train

# %%
for i in range(num_teachers):
    classifier = classifiers[i]
    criterion = nn.NLLLoss()
    classifier.to(device)
    
    test_loss = 0
    accuracy = 0
    classifier.eval()
    with torch.no_grad():
        preds_l1 = 0
        for inputs, labels in student_train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            logps = classifier.forward(inputs)
            batch_loss = criterion(logps, labels)

            test_loss += batch_loss.item()

            # Calculate accuracy
            ps = torch.exp(logps)
            top_p, top_class = ps.topk(1, dim=1)
            
            teacher_preds[i,preds_l1:(preds_l1 + batch_size)] = top_class.cpu().numpy().squeeze(1).astype(int)
            truths[preds_l1:(preds_l1 + batch_size)] = labels.cpu().numpy()
            if (preds_l1 + batch_size) >= num_examples:
                break
            preds_l1 += batch_size
            
    classifier.train()

# %% [markdown]
# Compute most votes

# %%
indices = utils.cal_max(teacher_preds, num_labels)

# %% [markdown]
# Analysis

# %%
from syft.frameworks.torch.differential_privacy import pate

data_dep_eps, data_ind_eps = pate.perform_analysis(teacher_preds=teacher_preds, indices=indices, noise_eps=2.5, delta=1e-6, moments=140)
print("Data Independent Epsilon:", data_ind_eps)
print("Data Dependent Epsilon:", data_dep_eps)
# Out:
# Data Independent Epsilon: 10240.098682218271
# Data Dependent Epsilon: 0.8644983575706948

# %% [markdown]
# #  Training student model

# %% [markdown]
# Choose privacy loss level same as noise_eps in the Analysis

# %%
privacy_loss_lv = 2.5

# %% [markdown]
# Apply Report Noisy Max algorithm

# %%
top_class = utils.noisy_max(teacher_preds, privacy_loss_lv, num_labels)
equals = top_class == truths
accuracy = np.mean(equals)
accuracy
# Out:
# 0.8447265625

# %% [markdown]
# Student

# %%
class Student(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(784, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 64)
        self.fc4 = nn.Linear(64, 10)
        
    def forward(self, x):
        # make sure input tensor is flattened
        x = x.view(x.shape[0], -1)
        
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.log_softmax(self.fc4(x), dim=1)
        
        return x
    
student_model = Student()

# %% [markdown]
# Training student

# %%
print_every = 100

criterion = nn.NLLLoss()

# Only train the classifier parameters, feature parameters are frozen
optimizer = optim.Adam(student_model.parameters(), lr=0.003)
student_model.to(device);

for epoch in range(epochs):
    steps = 0
    preds_l1 = 0
    for inputs, true_labels in student_train_loader:
        # Move input and label tensors to the default device
        inputs = inputs.to(device)
        
        # Return Report Noisy Max outputs
        labels = torch.tensor(utils.noisy_max(teacher_preds=teacher_preds[:,steps*batch_size:(steps+1)*batch_size]
                                              , privacy_loss_lv=privacy_loss_lv, n_labels=num_labels)).long()
        
        labels = labels.to(device)
        
        if steps % print_every != 0:
            optimizer.zero_grad()

            logps = student_model.forward(inputs)
            loss = criterion(logps, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        else:
            print(f"Epoch {epoch+1}/{epochs}.. "
                  f"Train loss: {running_loss/print_every:.3f}.. ")
            running_loss = 0
            
        if (preds_l1 + batch_size) >= num_examples:
            break
        preds_l1 += batch_size
            
        steps += 1
# Out:
# Epoch 1/15.. Train loss: 0.000..
# Epoch 2/15.. Train loss: 0.503..
# Epoch 3/15.. Train loss: 0.168..
# Epoch 4/15.. Train loss: 0.104..
# Epoch 5/15.. Train loss: 0.068..
# Epoch 6/15.. Train loss: 0.056..
# Epoch 7/15.. Train loss: 0.048..
# Epoch 8/15.. Train loss: 0.041..
# Epoch 9/15.. Train loss: 0.049..
# Epoch 10/15.. Train loss: 0.041..
# Epoch 11/15.. Train loss: 0.048..
# Epoch 12/15.. Train loss: 0.052..
# Epoch 13/15.. Train loss: 0.028..
# Epoch 14/15.. Train loss: 0.033..
# Epoch 15/15.. Train loss: 0.042..

# %% [markdown]
# Accuracy on the test set

# %%
criterion = nn.NLLLoss()
student_model.to(device);

test_loss = 0
accuracy = 0
student_model.eval()
with torch.no_grad():
    for inputs, labels in student_test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        logps = student_model.forward(inputs)
        batch_loss = criterion(logps, labels)

        test_loss += batch_loss.item()

        # Calculate accuracy
        ps = torch.exp(logps)
        top_p, top_class = ps.topk(1, dim=1)
        equals = top_class == labels.view(*top_class.shape)
        accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

print(f"Test loss: {test_loss/len(student_test_loader):.3f}.. "
      f"Test accuracy: {accuracy/len(student_test_loader):.3f}")
# Out:
# Test loss: 0.704.. Test accuracy: 0.871
